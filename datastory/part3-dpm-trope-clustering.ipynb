# %%
import os
import json
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F
from sklearn.metrics import adjusted_rand_score
from torch.utils.data import DataLoader
from torch.optim import Adam
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from scipy.sparse import hstack

# %%
bags_folder = '../data/char_bags' #Bag of words json file from build_char_word_bags.py output
tropes_file = '../data/tropes/tvtropes.clusters.txt' #tropes from CMU dataset

# %%
def load_character_bags(json_folder):
    character_bags = {}
    for filename in os.listdir(json_folder):
        if filename.endswith('.json'):
            with open(os.path.join(json_folder, filename)) as f:
                data = json.load(f)
                for character in data:
                    name = character['name']
                    bag_words = { "agent verb": [], "patient verb": [], "attribute": []}
                    for pair in character['bag']:
                        bag_words[pair[0]].append(pair[1])
                    
                    character_bags[name] = bag_words
    return character_bags

#load character bags of words
char_full = load_character_bags(bags_folder)

# %%
agent_texts = [" ".join(data["agent verb"]) for data in char_full.values()]
patient_texts = [" ".join(data["patient verb"]) for data in char_full.values()]
attribute_texts = [" ".join(data["attribute"]) for data in char_full.values()]

agent_vectorizer = CountVectorizer()
patient_vectorizer = CountVectorizer()
attribute_vectorizer = CountVectorizer()

agent_matrix = agent_vectorizer.fit_transform(agent_texts)
patient_matrix = patient_vectorizer.fit_transform(patient_texts)
attribute_matrix = attribute_vectorizer.fit_transform(attribute_texts)

agent_features = agent_vectorizer.get_feature_names_out()
patient_features = patient_vectorizer.get_feature_names_out()
attribute_features = attribute_vectorizer.get_feature_names_out()

combined_features = list(agent_features) + list(patient_features) + list(attribute_features)
dt_matrix = hstack([agent_matrix, patient_matrix, attribute_matrix])

print("Number of agent features:", len(agent_vectorizer.get_feature_names_out()))
print("Number of patient features:", len(patient_vectorizer.get_feature_names_out()))
print("Number of attribute features:", len(attribute_vectorizer.get_feature_names_out()))
print("Document-term matrix shape:\n", dt_matrix.shape)
# Out:
# Number of agent features: 9291
# Number of patient features: 8627
# Number of attribute features: 16799
# Document-term matrix shape:
#  (41529, 34717)

# %%
def load_tropes(tropes_file):
    trope_dict = {}
    with open(tropes_file) as f:
        for line in f:
            trope, char_data = line.split("\t")
            char_info = json.loads(char_data)
            name = char_info['char']
            trope_dict[name] = trope
    return trope_dict

#load character tropes
tropes = load_tropes(tropes_file)
print(f"Sample size: {len(tropes)}")
print(f"Number of unique tropes: {len(set(tropes.values()))}")
# Out:
# Sample size: 434
# Number of unique tropes: 72

# %%
from sklearn.decomposition import LatentDirichletAllocation

lda = LatentDirichletAllocation(n_components=72) 
persona_distributions = lda.fit_transform(dt_matrix)

for idx, topic in enumerate(lda.components_):
    top_indices = topic.argsort()[-5:][::-1]  # Top 5 words for this topic
    print(f"Persona {idx}: {[combined_features[i] for i in top_indices]}")
# Out:
# Persona 0: ['form', 'crush', 'meet', 'question', 'help']
# Persona 1: ['officer', 'take', 'investigate', 'have', 'discover']
# Persona 2: ['have', 'visit', 'lover', 'dump', 'have']
# Persona 3: ['old', 'father', 'year', 'sister', 'mary']
# Persona 4: ['have', 'king', 'advise', 'ben', 'brother']
# Persona 5: ['friend', 'pregnant', 'widow', 'worker', 'have']
# Persona 6: ['murder', 'kill', 'drug', 'star', 'dealer']
# Persona 7: ['joe', 'arrest', 'have', 'agree', 'tell']
# Persona 8: ['new', 'assist', 'focus', 'york', 'find']
# Persona 9: ['little', 'arrive', 'first', 'have', 'leave']
# Persona 10: ['girlfriend', 'have', 'be', 'go', 'tell']
# Persona 11: ['join', 'help', 'contact', 'find', 'kill']
# Persona 12: ['go', 'tell', 'tell', 'have', 'find']
# Persona 13: ['miss', 'sister', 'pregnant', 'host', 'leave']
# Persona 14: ['family', 'johnny', 'play', 'al', 'be']
# Persona 15: ['wealthy', 'rescue', 'willing', 'stick', 'end']
# Persona 16: ['queen', 'refuse', 'live', 'have', 'beat']
# Persona 17: ['discover', 'find', 'go', 'tell', 'have']
# Persona 18: ['know', 'boss', 'teacher', 'school', 'high']
# Persona 19: ['death', 'leader', 'de', 'lead', 'bob']
# Persona 20: ['mother', 'sam', 'attorney', 'recruit', 'send']
# Persona 21: ['include', 'attention', 'master', 'chris', 'win']
# Persona 22: ['consist', 'jimmy', 'sarah', 'kill', 'get']
# Persona 23: ['begin', 'best', 'battle', 'kill', 'terry']
# Persona 24: ['kidnap', 'go', 'assign', 'persuade', 'kill']
# Persona 25: ['husband', 'frank', 'reporter', 'uncle', 'prince']
# Persona 26: ['daughter', 'meet', 'be', 'fall', 'take']
# Persona 27: ['decide', 'be', 'meet', 'find', 'take']
# Persona 28: ['captain', 'call', 'sheriff', 'want', 'tell']
# Persona 29: ['tell', 'find', 'tell', 'decide', 'marry']
# Persona 30: ['paul', 'come', 'try', 'find', 'go']
# Persona 31: ['take', 'give', 'meet', 'go', 'leave']
# Persona 32: ['take', 'go', 'separate', 'manage', 'rape']
# Persona 33: ['second', 'kill', 'room', 'come', 'find']
# Persona 34: ['corrupt', 'have', 'find', 'agree', 'tell']
# Persona 35: ['wife', 'student', 'beautiful', 'meet', 'college']
# Persona 36: ['find', 'be', 'find', 'go', 'decide']
# Persona 37: ['dr', 'brother', 'kill', 'in', 'psychiatrist']
# Persona 38: ['mr', 'lord', 'detective', 'lawyer', 'bill']
# Persona 39: ['son', 'george', 'head', 'alice', 'try']
# Persona 40: ['name', 'kill', 'man', 'hand', 'find']
# Persona 41: ['live', 'harry', 'team', 'discover', 'take']
# Persona 42: ['singer', 'jim', 'deal', 'girl', 'businessman']
# Persona 43: ['kill', 'kill', 'attack', 'beat', 'stab']
# Persona 44: ['own', 'steve', 'peter', 'have', 'be']
# Persona 45: ['try', 'mike', 'have', 'decide', 'charge']
# Persona 46: ['impress', 'have', 'couple', 'charles', 'tell']
# Persona 47: ['friend', 'michael', 'sell', 'start', 'have']
# Persona 48: ['take', 'wedding', 'love', 'be', 'save']
# Persona 49: ['police', 'inspector', 'have', 'find', 'young']
# Persona 50: ['colonel', 'learn', 'have', 'tell', 'come']
# Persona 51: ['suggest', 'child', 'find', 'have', 'be']
# Persona 52: ['owner', 'marriage', 'richard', 'locate', 'gangster']
# Persona 53: ['couple', 'have', 'cousin', 'tony', 'escape']
# Persona 54: ['challenge', 'challenge', 'have', 'match', 'begin']
# Persona 55: ['relationship', 'boyfriend', 'move', 'billy', 'scientist']
# Persona 56: ['kill', 'fall', 'shoot', 'shoot', 'take']
# Persona 57: ['find', 'tell', 'aunt', 'go', 'be']
# Persona 58: ['interested', 'receive', 'have', 'assume', 'involve']
# Persona 59: ['nick', 'family', 'welcome', 'tell', 'minister']
# Persona 60: ['have', 'take', 'go', 'try', 'come']
# Persona 61: ['one', 'henry', 'princess', 'nurse', 'show']
# Persona 62: ['kill', 'bring', 'have', 'take', 'track']
# Persona 63: ['ex', 'major', 'escape', 'house', 'marry']
# Persona 64: ['fall', 'woman', 'be', 'meet', 'marry']
# Persona 65: ['accompany', 'kate', 'have', 'judge', 'find']
# Persona 66: ['tell', 'tell', 'love', 'love', 'go']
# Persona 67: ['james', 'learn', 'kidnap', 'mark', 'evil']
# Persona 68: ['agent', 'find', 'take', 'have', 'tell']
# Persona 69: ['mrs', 'have', 'greet', 'find', 'be']
# Persona 70: ['commander', 'have', 'lead', 'lt', 'artist']
# Persona 71: ['kill', 'lady', 'doctor', 'manager', 'member']

# %%
def get_overlapping_characters(character_bags, trope_dict):
    common_characters = set(character_bags.keys()).intersection(trope_dict.keys())
    filtered_bags = {name: character_bags[name] for name in common_characters}
    filtered_tropes = {name: trope_dict[name] for name in common_characters}
    return filtered_bags, filtered_tropes

#update the characaters and tropes to only include ones whose trope we know and who we have the bag of words for
char_filtered, tropes_filtered = get_overlapping_characters(char_full, tropes)

# %%
cluster_dict = {i: [] for i in range(len(set(tropes.values())))}

print("Prediction (Only showing characters who exist in tvtropes.clusters.txt:")
full_pred = persona_distributions.argmax(axis=1)
for name in list(char_filtered.keys()): 
    label = full_pred[list(char_full.keys()).index(name)]
    cluster_dict[label].append(name)
for cluster, characters in cluster_dict.items():
    print(f"Cluster {cluster}: {', '.join(characters)}")
print("\nGroundtruth:")
grouped_by_trope = {}
for name, trope in tropes_filtered.items():
    if trope not in grouped_by_trope:
        grouped_by_trope[trope] = []
    grouped_by_trope[trope].append(name)
for trope, characters in grouped_by_trope.items():
    print(f"{trope}: {', '.join(characters)}")
# Out:
# Prediction (Only showing characters who exist in tvtropes.clusters.txt:
# Cluster 0:
# Cluster 1: Ted "Theodore" Logan, Han, Belle
# Cluster 2: Karen
# Cluster 3:
# Cluster 4: Obi-Wan Kenobi, Agatha, Guy
# Cluster 5: Rooster, Leonard
# Cluster 6: Dreyfus, George McFly, Hannibal Lecter
# Cluster 7: Abu, Lucius Fox
# Cluster 8:
# Cluster 9: Ratchet, T. E. Lawrence, Dennis
# Cluster 10:
# Cluster 11: Sol
# Cluster 12: Sharpay Evans, Beth, Conan the Barbarian, Dorian Gray, Nick, Beck, Elle Woods, Van Wilder, Max Goldman, Mia Thermopolis
# Cluster 13:
# Cluster 14: Bo
# Cluster 15: Anakin Skywalker
# Cluster 16: Timothy, Apollo Creed, Cindy Campbell
# Cluster 17: James Norrington, Sheriff Woody, Max Rockatansky, Ed, James Bond, Wolverine, Frank Martin
# Cluster 18: Indiana Jones
# Cluster 19: Eli
# Cluster 20: Riley Poole, Sam Flynn
# Cluster 21: Blade
# Cluster 22: Brad
# Cluster 23: Arthur Bach, Ike Clanton, Garth, Carl Fredricksen, Doctor Doom
# Cluster 24: Jim
# Cluster 25: Mia
# Cluster 26:
# Cluster 27: Walter Burns, Tony Stark, Shaun
# Cluster 28: Randal Graves, Darth Vader, Hellboy, Austin, Giacomo Casanova
# Cluster 29: Kumar Patel
# Cluster 30: Pai Mei, Aragorn, Wendy Darling
# Cluster 31: Laurie Strode, Ethan Hunt, RoboCop, Mr. Kesuke Miyagi
# Cluster 32: Red
# Cluster 33: Otto, Han Solo
# Cluster 34:
# Cluster 35:
# Cluster 36: Vinny
# Cluster 37:
# Cluster 38:
# Cluster 39: Vincent
# Cluster 40: Jake, Justine, Man with No Name
# Cluster 41:
# Cluster 42:
# Cluster 43: Mina Harker, Blue, Nancy Thompson, Evelyn Carnahan-O'Connell
# Cluster 44: Sidney Prescott, Chico
# Cluster 45: Ian Hawke
# Cluster 46: Jack Walsh, Gen. Robert E. Lee, Vanessa, Tron
# Cluster 47: Chris, Ellen Ripley, Bill
# Cluster 48: Tom Sawyer, Clayton
# Cluster 49: Stu Price, Dean Richmond
# Cluster 50:
# Cluster 51:
# Cluster 52: Jay
# Cluster 53: Ben Stone
# Cluster 54: Daniel Jackson
# Cluster 55: Frank
# Cluster 56: Jason Bourne
# Cluster 57: Heathcliff
# Cluster 58: Gandalf, Loki, Lewis
# Cluster 59: Brandi
# Cluster 60: Harold Lee, Jimmy 'The Tulip' Tudeski
# Cluster 61: Gaston, Romy White, Henry Roth, Sarah Connor
# Cluster 62: Yoda, Count Dooku, Biff Tannen
# Cluster 63: Gary Winston
# Cluster 64: The Chief, Prince Humperdinck, The Sundance Kid
# Cluster 65: Mr. Bean, The Professor
# Cluster 66: Philip Marlowe, Marcia Brady, Commodus, Ashley
# Cluster 67: Captain Jack Sparrow, Captain Nemo
# Cluster 68:
# Cluster 69: Tyrone
# Cluster 70: Prince Edward, Agent Smith, John Preston
# Cluster 71: Morgan Earp
#
# Groundtruth:
# prima_donna: Sharpay Evans
# jerk_jock: Gaston, Biff Tannen, Bo, Garth, Jim, Austin
# granola_person: Beth, Ashley
# stupid_crooks: Sol, Tyrone, Vinny
# surfer_dude: Ted "Theodore" Logan
# eccentric_mentor: Yoda, Gandalf, Mr. Kesuke Miyagi
# casanova: Timothy, Giacomo Casanova
# slacker: Ben Stone, Shaun
# ditz: Mr. Bean, Nick, Arthur Bach, Henry Roth
# brainless_beauty: Chris, Brad, Marcia Brady
# young_gun: Jake, Morgan Earp, Tom Sawyer, Chico
# arrogant_kungfu_guy: Pai Mei, Han, Apollo Creed
# final_girl: Laurie Strode, Ellen Ripley, Sidney Prescott, Nancy Thompson, Sarah Connor
# the_chief: Dreyfus, The Chief
# romantic_runnerup: James Norrington, Prince Edward
# hardboiled_detective: Philip Marlowe
# valley_girl: Karen, Romy White, Elle Woods
# hitman_with_a_heart: Jason Bourne, Vincent, Jimmy 'The Tulip' Tudeski
# revenge: Conan the Barbarian, Leonard
# ophelia: Justine
# pupil_turned_to_evil: Count Dooku
# the_editor: Walter Burns
# corrupt_corporate_executive: Gary Winston, Ratchet, Doctor Doom, Ian Hawke
# bromantic_foil: Randal Graves, Ed
# crazy_jealous_guy: Otto, Heathcliff, Blue, Guy
# gadgeteer_genius: Tony Stark, Lucius Fox, Anakin Skywalker, Lewis
# adventurer_archaeologist: Indiana Jones, Evelyn Carnahan-O'Connell
# dumb_blonde: Brandi, Mia, Cindy Campbell
# doormat: Stu Price, George McFly, Belle
# fastest_gun_in_the_west: Sheriff Woody, RoboCop
# crazy_survivalist: Eli
# master_swordsman: Obi-Wan Kenobi, Darth Vader, Blade, Aragorn, Bill
# evil_prince: Prince Humperdinck, Commodus
# cultured_badass: Dorian Gray, Hannibal Lecter
# loveable_rogue: Abu, Wolverine
# junkie_prophet: Agatha
# heartbroken_badass: Mina Harker, Max Rockatansky, James Bond
# dean_bitterman: Dean Richmond
# trickster: Captain Jack Sparrow, Han Solo, Loki
# tranquil_fury: Ethan Hunt, John Preston
# bounty_hunter: Beck, Jack Walsh, Man with No Name
# big_man_on_campus: Van Wilder
# playful_hacker: Riley Poole, Sam Flynn
# stoner: Red, Harold Lee, Jay, Kumar Patel
# grumpy_old_man: Max Goldman, Carl Fredricksen
# coward: Ike Clanton
# father_to_his_men: Gen. Robert E. Lee, Captain Nemo
# consummate_professional: Agent Smith, The Professor, Frank Martin
# psycho_for_hire: Frank
# dirty_cop: Rooster
# warrior_poet: T. E. Lawrence
# bruiser_with_a_soft_center: Hellboy, Tron
# klutz: Mia Thermopolis
# absent_minded_professor: Daniel Jackson
# bully: Vanessa
# storyteller: Wendy Darling
# retired_outlaw: The Sundance Kid
# loser_protagonist: Dennis
# egomaniac_hunter: Clayton
