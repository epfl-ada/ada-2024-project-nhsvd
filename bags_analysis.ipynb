# %%
import numpy as np
import json
import os
import pandas as pd

from pathlib import Path

# %%
death_verbs_patient = {
    "kill", "murder", "execute", "assassinate", "slay",
    "behead", "crucify", "hang", "drown",
    "poison", "decapitate", "sacrifice", "eradicate",
    "annihilate", "exterminate", "obliterate", "destroy",
    "massacre", "euthanize", "lynch", "terminate"
}
    
death_verbs_agent = {
    "die", "commit", "perish", "sacrifice",
    "pass away", "expire", "succumb", 
    "surrender life", "bleed out"
}

def count_character_deaths(characters_bags):
    death_count = 0
    character_death_flags = {}
    
    for character in characters_bags:
        char_name = character['name']
        char_bag = character['bag']
        
        died = False
        
        for verb_type, verb in char_bag:
            if verb_type == 'patient verb' and verb in death_verbs_patient:
                died = True
                break
                
            if verb_type == 'agent verb' and verb in death_verbs_agent:
                died = True
                break
        
        character_death_flags[char_name] = 1 if died else 0
        
        if died:
            death_count += 1
    
    return death_count, character_death_flags

# %%
data_path = Path('data/processed')

records = {}

for movie in os.listdir(data_path):
    character_bags = json.load(open(data_path / movie))

    movie_id = movie.split('_')[-1].split('.')[0]

    num_deaths, character_deaths =  count_character_deaths(character_bags)

    records[movie_id] = {'num_deaths': num_deaths,
                         'num_characters': len(character_bags),
                         'character_deaths': character_deaths}

# %%
dict(sorted(records.items(), key=lambda item: item[1]['num_deaths'], reverse=True))
# Out:
# {'3238135': {'num_deaths': 9,
#   'num_characters': 12,
#   'character_deaths': {'Simon Cruise': 0,
#    'Greg': 1,
#    'Alicia': 0,
#    'Karma': 1,
#    'Cynthia': 1,
#    'Captain Victor Kirk': 1,
#    'Salish': 1,
#    'Jordan Casper': 1,
#    'Rudy Curien': 0,
#    'Liberty': 1,
#    'Hugh': 1,
#    'Castillo': 1}},
#  '714334': {'num_deaths': 8,
#   'num_characters': 11,
#   'character_deaths': {'Freddy Krueger': 1,
#    'Jason Voorhees': 1,
#    'Lori Campbell': 1,
#    'Trey': 1,
#    'Kia Waterson': 0,
#    'Gibb Smith': 1,
#    'Will Rollins': 0,
#    'Mark Davis': 1,
#    'Bill Freeburg': 1,
#    'Deputy Scott Stubbs': 0,
#    'Charlie Linderman': 1}},
#  '600351': {'num_deaths': 8,
#   'num_characters': 14,
#   'character_deaths': {'Cotton Weary': 1,
#    'Sidney Prescott': 0,
#    'Christine Hamilton': 1,
#    'Det. Mark Kincaid': 0,
#    'Gale Weathers': 1,
#    "Dwight 'Dewey' Riley": 0,
#    'Sarah Darling': 0,
#    'Jennifer Jolie': 1,
#    'Steven Stone': 0,
#    'Tom Prinze': 1,
#    'Angelina Tyler': 1,
#    'Tyson Fox': 0,
#    'Roman Bridger': 1,
#    'Maureen Roberts Prescott': 1}},
#  '1394579': {'num_deaths': 8,
#   'num_characters': 11,
#   'character_deaths': {'West': 1,
#    'Dunbar': 0,
#    'Kendall': 1,
#    'Mueller': 1,
#    'Osborne': 0,
#    'Styles': 1,
#    'Hardy': 1,
#    'Pike': 1,
#    'Castro': 1,
#    'Vilmer': 0,
#    'Nunez': 1}},
#  '19457040': {'num_deaths': 8,
#   'num_characters': 12,
#   'character_deaths': {'Garrett': 0,
#    'Megan': 1,
#    'Claire': 1,
#    'Jessica': 1,
#    'Ellie': 1,
#    'Chugs': 0,
#    'Cassidy': 0,
#    'Maggie': 1,
#    'Mickey': 1,
#    'Kyle': 1,
#    'Mrs. Crenshaw': 1,
#    'Andy': 0}},
#  '27485441': {'num_deaths': 8,
#   'num_characters': 11,
#   'character_deaths': {'Danny Bryce': 1,
#    'Hunter': 1,
#    'Davies': 1,
#    'Meier': 1,
#    'Agent': 0,
#    'Sheikh Amr': 1,
#    'Harris': 1,
#    'Capt. James Cregg': 1,
#    'McCann': 1,
#    'Bakhait': 0,
#    'Anne Frazier': 0}},
#  '4276475': {'num_deaths': 7,
#   'num_characters': 13,
#   'character_deaths': {'Joker': 0,
#    'Batman': 1,
#    'Harvey Dent': 0,
#    'Rachel Dawes': 1,
#    'Gambol': 1,
#    'The Chechen': 1,
#    'Lau': 1,
#    'Commissioner Gillian B. Loeb': 0,
#    'Alfred Pennyworth': 0,
#    'Mayor Anthony Garcia': 0,
#    'Coleman Reese': 1,
#    'Salvatore Maroni': 1,
#    'Lucius Fox': 0}},
#  '452767': {'num_deaths': 7,
#   'num_characters': 8,
#   'character_deaths': {'Selene': 1,
#    'Lucian': 1,
#    'Raze': 0,
#    'Kraven': 1,
#    'Michael Corvin': 1,
#    'Viktor': 1,
#    'Amelia': 1,
#    'Singe': 1}},
#  '15886402': {'num_deaths': 7,
#   'num_characters': 10,
#   'character_deaths': {"Nick O'Bannon": 0,
#    'Andy Kewzer': 1,
#    'Lori Milligan': 1,
#    'Janet Cunningham': 1,
#    'George Lanter': 1,
#    'Samantha Lane': 1,
#    'Carter Daniels': 1,
#    'Nadia Monroy': 1,
#    'Hunt Wynorski': 0,
#    'Jonathan Grove': 0}},
#  '10736919': {'num_deaths': 7,
#   'num_characters': 9,
#   'character_deaths': {'Light Yagami': 1,
#    'L': 1,
#    'Naomi Misora': 1,
#    'Shiori Akino': 1,
#    'Ryuk': 0,
#    'Misa Amane': 1,
#    'Kanzo Mogi': 1,
#    'Sayu Yagami': 1,
#    'Watari': 0}},
#  '538455': {'num_deaths': 7,
#   'num_characters': 13,
#   'character_deaths': {'Ana': 0,
#    'Michael': 0,
#    'Andre': 0,
#    'Luda': 1,
#    'Bart': 1,
#    'Norma': 1,
#    'Tucker': 1,
#    'Glen': 1,
#    'Frank': 1,
#    'Nicole': 0,
#    'Kenneth': 0,
#    'Steve': 1,
#    'Terry': 0}},
#  '2969247': {'num_deaths': 7,
#   'num_characters': 14,
#   'character_deaths': {'James Bond': 1,
#    'Mr. White': 0,
#    'M': 0,
#    'Mitchell': 0,
#    'Mr. Slate': 0,
#    'Camille Montes': 1,
#    'Dominic Greene': 0,
#    'General Medrano': 1,
#    'Gregg Beam': 0,
#    'Mathis': 1,
#    'Strawberry Fields': 1,
#    'Felix Leiter': 1,
#    'Vesper Lynd': 0,
#    'Yusef Kabira': 1}},
#  '1094719': {'num_deaths': 7,
#   'num_characters': 14,
#   'character_deaths': {'Takeo': 1,
#    'Kayako': 0,
#    'Toshio': 0,
#    'Peter': 1,
#    'Matthew': 1,
#    'Jennifer': 1,
#    'Emma': 0,
#    'Yoko': 0,
#    'Alex': 1,
#    'Karen': 1,
#    'Nakagawa': 0,
#    'Igarashi': 0,
#    'Susan': 0,
#    'Doug': 1}},
#  '707808': {'num_deaths': 7,
#   'num_characters': 13,
#   'character_deaths': {'Franky Four Fingers': 1,
#    "Doug 'The Head' Denovitz": 0,
#    "'Cousin' Avi Denovitz": 0,
#    "Boris 'The Blade' Yurinov": 1,
#    'Brick Top': 1,
#    'Turkish': 1,
#    "Mickey O'Neil": 1,
#    'Tyrone': 0,
#    'Sol': 0,
#    'Vinny': 0,
#    'Bad Boy Lincoln': 0,
#    'Bullet Tooth Tony': 1,
#    'Tommy': 1}},
#  '13053911': {'num_deaths': 7,
#   'num_characters': 9,
#   'character_deaths': {'Jason Voorhees': 0,
#    'Whitney Miller': 0,
#    'Nolan': 1,
#    'Jenna': 1,
#    'Bree': 1,
#    'Chewie': 1,
#    'Lawrence': 1,
#    'Clay Miller': 1,
#    'Chelsea': 1}},
#  '22044760': {'num_deaths': 7,
#   'num_characters': 10,
#   'character_deaths': {'Quintus Dias': 1,
#    'Vortix': 1,
#    'Virilus': 1,
#    'Etain': 1,
#    'Gorlacon': 0,
#    'Bothos': 0,
#    'Thax': 1,
#    'Brick': 1,
#    'Macros': 0,
#    'Tarak': 1}},
#  '12925911': {'num_deaths': 6,
#   'num_characters': 9,
#   'character_deaths': {'Richard Sitterson': 1,
#    'Steve Hadley': 1,
#    'Wendy Lin': 1,
#    'Dana Polk': 1,
#    'Curt Vaughan': 1,
#    'Woman in the woods': 0,
#    'Patience Buckner': 0,
#    'Jules Louden': 1,
#    'Marty Mikalski': 0}},
#  '3390263': {'num_deaths': 6,
#   'num_characters': 8,
#   'character_deaths': {'Emil Slovak': 1,
#    'Oleg Razgul': 1,
#    'Milos Karlova': 1,
#    'Daphne Handlova': 1,
#    'Fire Marshal Jordy Warsaw': 1,
#    'Detective Eddie Flemming': 1,
#    'Nicolette Karas': 0,
#    'Robert Hawkins': 0}},
#  '1364770': {'num_deaths': 6,
#   'num_characters': 8,
#   'character_deaths': {'Tom Welles': 1,
#    'Daniel Longdale': 1,
#    'Mrs. Christian': 1,
#    'Janet Mathews': 0,
#    'Max California': 1,
#    'Eddie Poole': 1,
#    'Dino Velvet': 1,
#    'George Higgins': 0}},
#  '1131021': {'num_deaths': 6,
#   'num_characters': 12,
#   'character_deaths': {'Elektra Natchios': 1,
#    'Stick': 0,
#    'DeMarco': 1,
#    'McCabe': 1,
#    'Abby Miller': 1,
#    'Mark Miller': 1,
#    'Roshi': 0,
#    'Kinkou': 1,
#    'Typhoid Mary': 0,
#    'Stone': 0,
#    'Tattoo': 0,
#    'Kirigi': 0}},
#  '3123893': {'num_deaths': 6,
#   'num_characters': 9,
#   'character_deaths': {'Walter Sullivan': 1,
#    'President Allen Richmond': 1,
#    'Luther Whitney': 1,
#    'Christy Sullivan': 1,
#    'Bill Burton': 1,
#    'Tim Collin': 0,
#    'Gloria Russell': 0,
#    'Seth Frank': 0,
#    'Kate Whitney': 1}},
#  '98991': {'num_deaths': 6,
#   'num_characters': 11,
#   'character_deaths': {'John Doe Jersey': 0,
#    'Bartleby': 0,
#    'Loki': 1,
#    'Metatron': 0,
#    'Bethany Sloane': 1,
#    'Silent Bob': 1,
#    'Rufus': 1,
#    'Serendipity': 1,
#    'Azrael': 1,
#    'Cardinal Glick': 0,
#    'Jay': 0}},
#  '5734461': {'num_deaths': 6,
#   'num_characters': 11,
#   'character_deaths': {'Kimberly': 0,
#    'Dale Murphy': 1,
#    'Nina Papas': 1,
#    'Amber': 1,
#    'Jake Washington': 0,
#    'Pa': 1,
#    'Mara': 0,
#    'Sister': 1,
#    'M': 0,
#    'Elena': 0,
#    'Brother': 1}},
#  '3036370': {'num_deaths': 6,
#   'num_characters': 12,
#   'character_deaths': {'Jack Foster': 1,
#    'Amanda Foster': 0,
#    'Harry': 1,
#    'George': 1,
#    'Ambassador Cochran': 0,
#    'Seaka': 1,
#    'Anya': 1,
#    'Schmitt': 0,
#    'Chambers': 0,
#    'Jensen': 0,
#    'Waters': 1,
#    'Cyrell': 0}},
#  '935847': {'num_deaths': 6,
#   'num_characters': 10,
#   'character_deaths': {'Michael McDonnell, gas station attendant': 0,
#    'Parker Riley': 1,
#    'Natalie Simon': 1,
#    'Nurse Brenda Bates': 0,
#    'Sasha Thomas': 1,
#    'Paul Gardener': 0,
#    'Damon Brooks': 1,
#    'Tosh Guaneri': 1,
#    'Professor William Wexler': 1,
#    'Reese Wilson': 0}},
#  '18436536': {'num_deaths': 6,
#   'num_characters': 14,
#   'character_deaths': {'Adrian Helmsley': 0,
#    'Dr. Satnam Tsurutani': 0,
#    'Carl Anheuser': 0,
#    'President Thomas Wilson': 1,
#    'Tenzin': 0,
#    'Laura Wilson': 0,
#    'Jackson Curtis': 0,
#    'Yuri Karpov': 1,
#    'Kate Curtis': 0,
#    'Gordon Silberman': 1,
#    'Charlie Frost': 1,
#    'Tamara': 1,
#    'Sasha': 1,
#    'Noah Curtis': 0}},
#  '1025150': {'num_deaths': 6,
#   'num_characters': 11,
#   'character_deaths': {'Adam Faulkner-Stanheight': 1,
#    'Lawrence Gordon': 1,
#    'Allison Kerry': 1,
#    'Diana Gordon': 1,
#    'Jigsaw Killer': 0,
#    'Zep Hindle': 0,
#    'David Tapp': 0,
#    'Detective Steven Sing': 1,
#    'Amanda Young': 0,
#    'Paul': 0,
#    'Alison Gordon': 1}},
#  '1164544': {'num_deaths': 6,
#   'num_characters': 8,
#   'character_deaths': {'Malcolm Rivers': 0,
#    'Rhodes': 1,
#    'George York': 1,
#    'Robert Maine': 1,
#    'Ed': 0,
#    'Ginny': 1,
#    'Larry': 1,
#    'Paris': 1}},
#  '3158499': {'num_deaths': 6,
#   'num_characters': 6,
#   'character_deaths': {'Bishop': 1,
#    'Q': 1,
#    'Raheem': 1,
#    'Steel': 1,
#    'Radames': 1,
#    'Quiles': 1}},
#  '3024248': {'num_deaths': 6,
#   'num_characters': 11,
#   'character_deaths': {'Loomis Crowley': 1,
#    'Hutch MacNeil': 0,
#    'Miller Banks': 1,
#    'Abigail': 1,
#    'October Bantum': 0,
#    'Swink Sylvania': 1,
#    'Contessa Bathory': 1,
#    'Detective Thibodeaux': 0,
#    'Detective King': 1,
#    'Phineus Bantum': 0,
#    'Jonathan Malkus': 0}},
#  '3284664': {'num_deaths': 6,
#   'num_characters': 7,
#   'character_deaths': {'Pete Garrison': 1,
#    'First Lady Sarah Ballentine': 1,
#    'Mrs. Merriweather': 1,
#    'President Ballentine': 1,
#    'David Breckinridge': 1,
#    'Jill Marin': 0,
#    'William Montrose': 1}},
#  '129644': {'num_deaths': 6,
#   'num_characters': 15,
#   'character_deaths': {'Michael Corleone': 1,
#    'Joey Zasa': 1,
#    'Kay Adams': 0,
#    'Anthony Corleone': 0,
#    'Mary Corleone': 1,
#    'Connie Corleone': 0,
#    'Vincent Mancini-Corleone': 1,
#    'Grace Hamilton': 0,
#    'Archbishop Gilday': 0,
#    'Don Altobello': 1,
#    'Al Neri': 0,
#    'Don Tommasino': 0,
#    'Don Licio Lucchesi': 0,
#    'Frederick Keinszig': 1,
#    'Cardinal Lamberto': 0}},
#  '479757': {'num_deaths': 6,
#   'num_characters': 11,
#   'character_deaths': {'Blade': 0,
#    'Abraham Whistler': 1,
#    'Scud': 1,
#    'Jared Nomak': 1,
#    'Eli Damaskinos': 1,
#    'Asad': 0,
#    'Nyssa': 0,
#    'Kounen': 0,
#    'Chupa': 1,
#    'Snowman': 1,
#    'Verlaine': 0}},
#  '7694669': {'num_deaths': 6,
#   'num_characters': 13,
#   'character_deaths': {'John Kramer': 1,
#    'Mark Hoffman': 0,
#    'Art Blank': 1,
#    'Allison Kerry': 0,
#    'Peter Strahm': 0,
#    'Lindsey Perez': 0,
#    'Amanda Young': 0,
#    'Rigg': 1,
#    'Detective Eric Matthews': 1,
#    'Ivan Landsness': 1,
#    'Cecil Adams': 1,
#    'Jill Tuck-Kramer': 0,
#    'Lynn Denlon': 0}},
#  '31941988': {'num_deaths': 6,
#   'num_characters': 17,
#   'character_deaths': {'Lord Voldemort': 1,
#    'Professor Albus Dumbledore': 0,
#    'Professor Severus Snape': 1,
#    'Harry Potter': 1,
#    'Griphook': 0,
#    'Hermione Granger': 0,
#    'Bellatrix Lestrange': 1,
#    'Mr Ollivander': 0,
#    'Draco Malfoy': 0,
#    'Helena Ravenclaw': 0,
#    'Aberforth Dumbledore': 0,
#    'Ariana Dumbledore': 0,
#    'Neville Longbottom': 0,
#    'Professor Minerva McGonagall': 0,
#    'Remus Lupin': 1,
#    'Nymphadora Tonks': 1,
#    'Molly Weasley': 0}},
#  '22816824': {'num_deaths': 6,
#   'num_characters': 9,
#   'character_deaths': {'Goemon Ishikawa': 1,
#    'Nobunaga Oda': 1,
#    'Chacha Asai': 0,
#    'Hideyoshi Toyotomi': 1,
#    'Saizo Kirigakure': 1,
#    'Sasuke Sarutobi': 0,
#    'Mitsunari Ishida': 1,
#    'Hanzo Hattori': 0,
#    'Ieyasu Tokugawa': 1}},
#  '443011': {'num_deaths': 6,
#   'num_characters': 8,
#   'character_deaths': {'Lara Croft': 1,
#    'Chen Lo': 0,
#    'Jonathan Reiss': 0,
#    'Terry Sheridan': 1,
#    'Bryce': 1,
#    'Hillary': 1,
#    'Kosa': 1,
#    'Sean': 1}},
#  '145892': {'num_deaths': 6,
#   'num_characters': 9,
#   'character_deaths': {'Jim': 1,
#    'Selena': 0,
#    'Mark': 1,
#    'Frank': 1,
#    'Hannah': 0,
#    'Major Henry West': 0,
#    'Sergeant Farrell': 1,
#    'Private Mailer': 1,
#    'Corporal Mitchell': 1}},
#  '3038038': {'num_deaths': 6,
#   'num_characters': 9,
#   'character_deaths': {'Kristen Parker': 1,
#    'Joey Crusel': 0,
#    'Roland Kincaid': 1,
#    'Alice Johnson': 1,
#    'Sheila Kopecky': 1,
#    'Debbie Stevens': 1,
#    'Rick Johnson': 0,
#    'Freddy Krueger': 1,
#    'Dan Jordan': 0}},
#  '21000149': {'num_deaths': 6,
#   'num_characters': 12,
#   'character_deaths': {'Lou Ford': 0,
#    'Mike': 1,
#    'Chester Conway': 0,
#    'Joyce Lakeland': 1,
#    'Elmer Conway': 1,
#    'Sheriff Bob Maples': 1,
#    'Amy Stanton': 1,
#    'Howard Hendricks': 0,
#    'Johnnie Pappas': 1,
#    'Joe Rothman': 0,
#    'Deputy Jeff Plummer': 0,
#    'Billy Boy Walker': 0}},
#  '6152265': {'num_deaths': 6,
#   'num_characters': 11,
#   'character_deaths': {'Colonel Jacques Bouvar': 1,
#    'James Bond': 1,
#    'M': 0,
#    'Patricia Fearing': 0,
#    'Count Lippe': 1,
#    'Domino Derval': 1,
#    'Emilio Largo': 1,
#    'Fiona Volpe': 0,
#    'Felix Leiter': 0,
#    'Q': 0,
#    'Paula Caplan': 1}},
#  '725984': {'num_deaths': 5,
#   'num_characters': 14,
#   'character_deaths': {'Stooge': 0,
#    'Little Face': 0,
#    'Flattop': 0,
#    'Big Boy Caprice': 1,
#    'Dick Tracy': 1,
#    'Lips Manlis': 1,
#    'Breathless Mahoney': 0,
#    'Itchy': 0,
#    'Mumbles': 0,
#    'Spaldoni': 0,
#    'Pruneface': 1,
#    '88 Keys': 0,
#    'D.A. Fletcher': 1,
#    'Tess Trueheart': 0}},
#  '17789399': {'num_deaths': 5,
#   'num_characters': 9,
#   'character_deaths': {'Jimmy': 1,
#    'Fletch': 0,
#    'Vicar': 1,
#    'Carmilla': 1,
#    'Eva': 1,
#    'Anke': 0,
#    'Trudi': 0,
#    'Lotte': 1,
#    'Rebecca': 0}},
#  '174251': {'num_deaths': 5,
#   'num_characters': 16,
#   'character_deaths': {'Gimli': 1,
#    'Aragorn': 0,
#    'Legolas': 0,
#    'Treebeard': 0,
#    'Frodo Baggins': 1,
#    'Gandalf': 0,
#    'Denethor': 1,
#    'Faramir': 0,
#    'Elrond': 0,
#    'Arwen': 1,
#    'King of the Dead': 0,
#    'Witch-king of Angmar': 1,
#    'Gollum': 0,
#    'Rosie Cotton': 0,
#    'Bilbo Baggins': 0,
#    'Galadriel': 0}},
#  '5187488': {'num_deaths': 5,
#   'num_characters': 6,
#   'character_deaths': {'Felix Ramirez': 1,
#    'Leonard Purckett': 1,
#    'Sgt. Bill Dane': 0,
#    'Cpl. Barney Todd': 1,
#    'Lt. Steve Bentley': 1,
#    'Cpl. Jake Feingold': 1}},
#  '957322': {'num_deaths': 5,
#   'num_characters': 10,
#   'character_deaths': {'Memnon': 1,
#    'Jesup': 0,
#    'King Pheron': 1,
#    'Cassandra': 1,
#    'Takmet': 1,
#    'Arpid': 0,
#    'Queen Isis': 0,
#    'Philos': 0,
#    'Thorak': 1,
#    'Balthazar': 0}},
#  '957928': {'num_deaths': 5,
#   'num_characters': 9,
#   'character_deaths': {'Marion Chambers': 1,
#    'Jimmy Howell': 0,
#    'Laurie Strode': 1,
#    'Michael Myers': 1,
#    'John Tate': 1,
#    'Will Brennan': 0,
#    'Norma Watson': 0,
#    'Sarah Wainthrope': 1,
#    'Molly Cartwell': 0}},
#  '13838662': {'num_deaths': 5,
#   'num_characters': 8,
#   'character_deaths': {'Tim Boyle': 0,
#    "Detective Antonio 'Tony' Ricci": 0,
#    '2nd Staff Sergeant Aubrey Stamps': 1,
#    'Sergeant Bishop Cummings': 1,
#    'Private First Class Sam Train': 1,
#    'Angelo Torancelli (The Boy)': 1,
#    'Corporal Hector Negron': 0,
#    'Renata': 1}},
#  '2246413': {'num_deaths': 5,
#   'num_characters': 7,
#   'character_deaths': {'Ghost Rider': 0,
#    'Mephisto': 0,
#    'Young Johnny Blaze': 1,
#    'Blackheart': 1,
#    'Gressil': 1,
#    'Roxanne Simpson': 1,
#    'Mack': 1}},
#  '1854000': {'num_deaths': 5,
#   'num_characters': 11,
#   'character_deaths': {'Jason Bourne': 1,
#    'Martin Kreutz': 0,
#    'Simon Ross': 1,
#    'Paz': 0,
#    'Noah Vosen': 0,
#    'Pamela Landy': 0,
#    'Neal Daniels': 1,
#    'Nicky Parsons': 1,
#    'Desh': 1,
#    'Dr. Albert Hirsch': 0,
#    'Ezra Kramer': 0}},
#  '230481': {'num_deaths': 5,
#   'num_characters': 8,
#   'character_deaths': {'Hawkins': 0,
#    'Dillon': 1,
#    'Dutch': 0,
#    'Anna': 0,
#    'Blain': 1,
#    'Mac': 1,
#    'Poncho': 1,
#    'Billy': 1}},
#  '27907826': {'num_deaths': 5,
#   'num_characters': 8,
#   'character_deaths': {'Vinayak Mahadevan': 1,
#    'Faizal': 0,
#    'Prithvi': 1,
#    'Sanjana': 0,
#    'Sumanth': 0,
#    'Ganesh': 1,
#    'Prem': 1,
#    'Sona': 1}},
#  '1278575': {'num_deaths': 5,
#   'num_characters': 10,
#   'character_deaths': {'Williams': 0,
#    'Margaret': 1,
#    'Jacob Goodnight': 1,
#    'Richie': 0,
#    'Michael': 0,
#    'Kira': 1,
#    'Hannah': 1,
#    'Christine': 0,
#    'Zoe': 1,
#    'Melissa': 0}},
#  '34004383': {'num_deaths': 5,
#   'num_characters': 5,
#   'character_deaths': {'Emma Nash': 1,
#    'David Nash': 1,
#    'Trish Garrety': 1,
#    'Ray Jaffe': 1,
#    'Andy Spector': 1}},
#  '11701': {'num_deaths': 5,
#   'num_characters': 8,
#   'character_deaths': {'Gny. Sgt. Hartman': 1,
#    'Pvt. Cowboy': 1,
#    "Pvt. Leonard 'Gomer Pyle' Lawrence": 0,
#    'Rafterman': 0,
#    'Crazy Earl': 1,
#    'Eightball': 1,
#    'Doc Jay': 1,
#    'Animal Mother': 0}},
#  '997918': {'num_deaths': 5,
#   'num_characters': 9,
#   'character_deaths': {'Tom Mullen': 0,
#    'Kate Mullen': 0,
#    'Sean Mullen': 1,
#    'Maris Conner': 0,
#    'Clark Barnes': 1,
#    'Cubby Barnes': 1,
#    'Miles Roberts': 1,
#    'Det. Jimmy Shaker': 1,
#    'Agent Lonnie Hawkins': 0}},
#  '2269465': {'num_deaths': 5,
#   'num_characters': 15,
#   'character_deaths': {'Jason Voorhees': 1,
#    'Dr. Wimmer': 0,
#    'Rowan': 0,
#    'Tsunaron': 0,
#    'Janessa': 0,
#    'Azrael': 1,
#    'Prof. Lowe': 1,
#    'Kinsa': 0,
#    'Waylander': 0,
#    'Stoney': 0,
#    'Adrienne': 0,
#    'Dieter Perez': 1,
#    'Sgt. Brodski': 0,
#    'Crutch': 1,
#    'Lou': 0}},
#  '3226774': {'num_deaths': 5,
#   'num_characters': 14,
#   'character_deaths': {'Mrs. Davis': 0,
#    'Aubrey': 1,
#    'Eason': 1,
#    'Karen': 0,
#    'Toshio': 0,
#    'Kayako': 0,
#    'Takeo': 1,
#    'Allison': 0,
#    'Vanessa': 0,
#    'Miyuki': 1,
#    'Trish': 0,
#    'Sally': 1,
#    'Lacey': 0,
#    'Jake': 0}},
#  '1748912': {'num_deaths': 5,
#   'num_characters': 6,
#   'character_deaths': {'Charlie Strom': 1,
#    'Lee': 1,
#    'Johnny North': 1,
#    'Earl Sylvester': 0,
#    'Sheila Farr': 1,
#    'Jack Browning': 1}},
#  '2982688': {'num_deaths': 5,
#   'num_characters': 9,
#   'character_deaths': {'James Howlett': 0,
#    'William Stryker': 1,
#    'Professor X': 0,
#    'Agent Zero': 1,
#    'John Wraith': 1,
#    'Wolverine': 0,
#    'Kayla Silver Fox': 1,
#    'Gambit': 0,
#    'Deadpool': 1}},
#  '23941382': {'num_deaths': 5,
#   'num_characters': 13,
#   'character_deaths': {'King Hyperion': 0,
#    'Phaedra': 0,
#    'Theseus': 0,
#    'Lysander': 1,
#    'Helios': 1,
#    'Apollo': 0,
#    'Poseidon': 0,
#    'Zeus': 0,
#    'Stavros': 1,
#    'Minotaur': 1,
#    'Athena': 0,
#    'Cassander': 1,
#    'Heracles': 0}},
#  '449547': {'num_deaths': 5,
#   'num_characters': 12,
#   'character_deaths': {'Felix Leiter': 0,
#    'Franz Sanchez': 1,
#    'James Bond': 1,
#    'Ed Killifer': 1,
#    'Della Churchill': 1,
#    'M': 0,
#    'Milton Krest': 0,
#    'Pam Bouvier': 1,
#    'Dario': 0,
#    'Fallon': 0,
#    'Q': 0,
#    'Truman-Lodge': 0}},
#  '12319832': {'num_deaths': 5,
#   'num_characters': 15,
#   'character_deaths': {'Major William Lennox': 0,
#    'Optimus Prime': 1,
#    'Soundwave': 0,
#    'Sam Witwicky': 0,
#    'Mikaela Banes': 0,
#    'Megatron': 1,
#    'Wheelie': 0,
#    'Leo Spitz': 0,
#    'Alice': 1,
#    'Fallen': 1,
#    'Starscream': 0,
#    'Skids': 0,
#    'Reggie Simmons': 0,
#    'Devastator': 1,
#    'Robert Epps': 0}},
#  '1891886': {'num_deaths': 5,
#   'num_characters': 7,
#   'character_deaths': {'Evey Hammond': 1,
#    'V': 1,
#    'Deitrich': 1,
#    'Valerie': 0,
#    'Finch': 0,
#    'Adam Sutler': 1,
#    'Creedy': 1}},
#  '2206417': {'num_deaths': 5,
#   'num_characters': 9,
#   'character_deaths': {'Baron Victor von Frankenstein': 0,
#    'Doctor Hertz': 0,
#    'Hans': 1,
#    'Christina': 1,
#    'Kleve': 0,
#    'Johann': 1,
#    'The Prisoner': 0,
#    'Anton': 1,
#    'Karl': 1}},
#  '206845': {'num_deaths': 5,
#   'num_characters': 9,
#   'character_deaths': {'Z': 1,
#    'Weaver': 0,
#    'Princess Bala': 0,
#    'Barbatus': 1,
#    'General Mandible': 1,
#    'Queen': 1,
#    'Colonel Cutter': 1,
#    'Chip': 0,
#    'Muffy': 0}},
#  '3030953': {'num_deaths': 5,
#   'num_characters': 6,
#   'character_deaths': {'Eklavya': 1,
#    'Prince Harshwardhan': 1,
#    'Queen Suhasinidevi': 1,
#    'Princess Nandini': 0,
#    'Jyotiwardhan': 1,
#    'Udaywardhan': 1}},
#  '561315': {'num_deaths': 5,
#   'num_characters': 14,
#   'character_deaths': {'Dorothy Gale': 1,
#    'Aunt Em': 0,
#    'Uncle Henry': 0,
#    'Hickory': 0,
#    'Hunk': 0,
#    'Elmira Gulch': 1,
#    'Toto': 1,
#    'Professor Marvel': 0,
#    'Glinda': 0,
#    'Wicked Witch of the East': 1,
#    'The Wizard': 0,
#    'Scarecrow': 0,
#    'Tin Man': 0,
#    'Cowardly Lion': 1}},
#  '1011854': {'num_deaths': 5,
#   'num_characters': 9,
#   'character_deaths': {'Adrian': 1,
#    'Cassius': 0,
#    'Nicky': 1,
#    'Mr. Beefy': 0,
#    'Todd': 1,
#    'Valerie Veran': 0,
#    'John': 1,
#    'Peter': 1,
#    'Chief of Police': 0}},
#  '16794053': {'num_deaths': 5,
#   'num_characters': 15,
#   'character_deaths': {'Angela Vidal': 1,
#    'Scott Percival': 0,
#    'Jake': 0,
#    'Yuri Ivanov': 0,
#    'George Fletcher': 0,
#    'James McCreedy': 0,
#    'Lawrence': 0,
#    'Danny Wilensky': 0,
#    'Randy': 0,
#    'Elise Jackson': 0,
#    'Briana': 1,
#    'Kathy': 1,
#    'Sadie': 1,
#    'Bernard': 1,
#    'Wanda Marimon': 0}},
#  '24131841': {'num_deaths': 5,
#   'num_characters': 8,
#   'character_deaths': {'Tammy': 1,
#    'Kristen': 0,
#    'Iris': 1,
#    'Sarah': 0,
#    'Emily': 1,
#    'Zoey': 1,
#    'Dr. Stringer': 0,
#    'Alice': 1}},
#  '2950304': {'num_deaths': 5,
#   'num_characters': 13,
#   'character_deaths': {'Ira Hayes': 1,
#    'Rene Gagnon': 0,
#    'Mike Strank': 1,
#    'Harlon Block': 1,
#    'Franklin Sousley': 1,
#    'Hank Hansen': 1,
#    'Ralph "Iggy" Ignatowski': 0,
#    'Captain Severance': 0,
#    'Colonel Chandler Johnson': 0,
#    'Keyes Beech': 0,
#    'Bud Gerber': 0,
#    'Commandant Vandegrift': 0,
#    'James Bradley': 0}},
#  '548259': {'num_deaths': 5,
#   'num_characters': 11,
#   'character_deaths': {'Dr. Victor Frankenstein': 1,
#    'Count Vladislaus Dracula': 1,
#    "Frankenstein's monster": 0,
#    'Verona': 0,
#    'Aleera': 0,
#    'Marishka': 1,
#    'Gabriel Van Helsing': 1,
#    'Carl': 0,
#    'Anna Valerious': 0,
#    'Velkan Valerious': 1,
#    'Igor': 0}},
#  '915499': {'num_deaths': 5,
#   'num_characters': 9,
#   'character_deaths': {'Kaufman': 1,
#    'Riley Denbo': 1,
#    'Big Daddy': 1,
#    'Slack': 1,
#    'Charlie': 0,
#    'Cholo DeMora': 1,
#    'Pretty Boy': 0,
#    'Foxy': 0,
#    'Motown': 0}},
#  '80405': {'num_deaths': 5,
#   'num_characters': 6,
#   'character_deaths': {'Johnny Mnemonic': 1,
#    'Takahashi': 1,
#    'Shinji': 1,
#    'J-Bone': 0,
#    'Spider': 1,
#    'Street Preacher': 1}},
#  '4607218': {'num_deaths': 5,
#   'num_characters': 14,
#   'character_deaths': {'Prof. Joyce Reardon': 0,
#    'Ellen Rimbauer': 1,
#    'Sukeena': 0,
#    'Young Steven Rimbauer': 0,
#    'Annie Wheaton': 1,
#    'Rachel Wheaton': 0,
#    'Kevin Bollinger': 1,
#    'Professor Carl Miller': 0,
#    'Victor Kandinsky': 1,
#    'Pam Asbury': 0,
#    'Cathy Kramer': 0,
#    'Nick Hardaway': 0,
#    'Emery Waterman': 1,
#    'Actress Deanna Petrie': 0}},
#  '1882179': {'num_deaths': 5,
#   'num_characters': 14,
#   'character_deaths': {'Caspian X': 1,
#    'Doctor Cornelius': 0,
#    'Queen Prunaprismia': 0,
#    'Susan Pevensie': 0,
#    'Miraz': 1,
#    'Trumpkin': 0,
#    'Trufflehunter': 0,
#    'Nikabrik': 0,
#    'Lord Sopespian': 1,
#    'Lucy Pevensie': 1,
#    'Edmund Pevensie': 0,
#    'Aslan': 0,
#    'Peter Pevensie': 0,
#    'White Witch': 1}},
#  '4846576': {'num_deaths': 5,
#   'num_characters': 10,
#   'character_deaths': {'Patrick Bateman': 1,
#    'Evelyn Williams': 0,
#    'Paul Allen': 1,
#    'Detective Donald Kimball': 0,
#    'Luis Carruthers': 1,
#    'Jean': 1,
#    'Elizabeth': 1,
#    'Christie': 0,
#    'Al, the Derelict': 0,
#    'Harold Carnes': 0}},
#  '12940547': {'num_deaths': 5,
#   'num_characters': 8,
#   'character_deaths': {'The Scientist': 1,
#    '9': 1,
#    '2': 1,
#    '1': 1,
#    '5': 1,
#    '7': 0,
#    '6': 0,
#    '8': 0}},
#  '6142808': {'num_deaths': 5,
#   'num_characters': 13,
#   'character_deaths': {'Jake': 1,
#    'Dr. Sullivan': 0,
#    'Kayako': 1,
#    'Naoko': 1,
#    'Daisuke': 0,
#    'Max': 1,
#    'Rose': 0,
#    'Renee': 1,
#    'Brenda': 0,
#    'Gretchen': 0,
#    'Lisa': 0,
#    'Toshio': 0,
#    'Andy': 0}},
#  '255049': {'num_deaths': 5,
#   'num_characters': 8,
#   'character_deaths': {'Helen Shivers': 0,
#    'Julie James Bronson': 0,
#    'Barry William Cox': 0,
#    'Ray Bronson': 1,
#    'Max Neurick': 1,
#    'Benjamin Willis': 1,
#    "Melissa 'Missy' Egan": 1,
#    'Elsa Shivers': 1}},
#  '670226': {'num_deaths': 5,
#   'num_characters': 6,
#   'character_deaths': {'Dame Vaako': 1,
#    'Toombs': 0,
#    'Imam': 1,
#    'Lord Marshal': 1,
#    'Kyra': 1,
#    'Purifier': 1}},
#  '19787914': {'num_deaths': 5,
#   'num_characters': 15,
#   'character_deaths': {'Jenny Randall': 0,
#    'Marnie Cooper': 0,
#    'Ghostface': 1,
#    'Sidney Prescott': 0,
#    'Rebecca Walters': 0,
#    'Jill Kessler': 1,
#    'Trevor Sheldon': 0,
#    'Olivia Morris': 1,
#    'Kirby Reed': 0,
#    "Dwight 'Dewey' Riley": 0,
#    'Deputy Judy Hicks': 0,
#    'Kate Roberts': 1,
#    'Gale Weathers': 0,
#    'Charlie Walker': 1,
#    'Robbie Mercer': 0}},
#  '30470648': {'num_deaths': 5,
#   'num_characters': 9,
#   'character_deaths': {'Agenor': 1,
#    'Zeus': 1,
#    'Ares': 1,
#    'Hades': 0,
#    'Poseidon': 0,
#    'Hephaestus': 1,
#    'Perseus': 0,
#    'Andromeda': 0,
#    'Minotaur': 1}},
#  '570350': {'num_deaths': 5,
#   'num_characters': 8,
#   'character_deaths': {'Terry Brogan': 1,
#    'Jake Wise': 1,
#    'Mrs. Wyler': 1,
#    'Jessie Wyler': 0,
#    'Ben Caxton': 0,
#    'Hank Sully': 1,
#    'Steve Kirsch': 1,
#    'Edie': 0}},
#  '3606413': {'num_deaths': 5,
#   'num_characters': 6,
#   'character_deaths': {'Spencer Olham': 1,
#    'Hathaway': 1,
#    'Chancellor': 1,
#    'Nelson Gittes': 1,
#    'Cale': 0,
#    'Maya Olham': 1}},
#  '3487956': {'num_deaths': 5,
#   'num_characters': 13,
#   'character_deaths': {'Ethel Carter': 1,
#    'Lynn Carter': 1,
#    'Bobby Carter': 0,
#    'Doug Bukowski': 1,
#    'Big Bob Carter': 0,
#    'Ruby': 0,
#    'Papa Jupiter': 1,
#    'Lizard': 0,
#    'Pluto': 0,
#    'Goggle': 0,
#    'Big Mama': 0,
#    'Big Brain': 1,
#    'Cyst': 0}},
#  '6098808': {'num_deaths': 5,
#   'num_characters': 8,
#   'character_deaths': {'Jamie Ashen': 1,
#    'Lisa Ashen': 1,
#    'Mary Shaw': 1,
#    'Det. Lipton': 1,
#    'Ella Ashen': 0,
#    'Marion Walker': 0,
#    'Henry Walker': 1,
#    'Michael Ashen': 0}},
#  '75984': {'num_deaths': 5,
#   'num_characters': 8,
#   'character_deaths': {'Lord Hidetora Ichimonji': 1,
#    'Taro Takatora Ichimonji': 1,
#    'Jiro Masatora Ichimonji': 1,
#    'Saburo Naotora Ichimonji': 1,
#    'Tango Hirayama': 0,
#    'Lady Kaede': 1,
#    'Shuri Kurogane': 0,
#    'Lady Sue': 0}},
#  '26255812': {'num_deaths': 5,
#   'num_characters': 11,
#   'character_deaths': {'Allison': 0,
#    'Chad': 1,
#    'Chloe': 1,
#    'Chuck': 0,
#    'Jason': 0,
#    'Naomi': 1,
#    'Todd': 0,
#    'Mitch': 0,
#    'Mike': 0,
#    'Tucker': 1,
#    'Dale': 1}},
#  '23887068': {'num_deaths': 5,
#   'num_characters': 11,
#   'character_deaths': {'Averill': 0,
#    'Osmund': 0,
#    'Mold': 1,
#    'Ivo': 1,
#    'Swire': 0,
#    'Griff': 1,
#    'Wolfstan': 0,
#    'Hob': 0,
#    'Langiva': 0,
#    'Ulric': 1,
#    'Dalywag': 1}},
#  '328344': {'num_deaths': 5,
#   'num_characters': 9,
#   'character_deaths': {'Chris Collins': 1,
#    'Jerry Manley': 1,
#    'Irv Kendall': 0,
#    'Dr. Ross Jennings': 0,
#    'Molly Jennings': 1,
#    'Margaret Hollins': 1,
#    'Doctor Sam Metcalf': 1,
#    'Milton Briggs': 0,
#    'Delbert McClintock': 0}},
#  '4270540': {'num_deaths': 5,
#   'num_characters': 7,
#   'character_deaths': {'Doc Potter': 1,
#    'Ben Wade': 0,
#    'Byron McElroy': 1,
#    'Grayson Butterfield': 0,
#    'William Evans': 1,
#    'Zeke': 1,
#    'Charlie Prince': 1}},
#  '23658618': {'num_deaths': 5,
#   'num_characters': 10,
#   'character_deaths': {'Deputy Ally Lane': 0,
#    'Walter': 0,
#    'Preslow': 1,
#    'Crawford': 1,
#    'Floyd': 0,
#    'Chavez': 1,
#    'Willy Juarez': 1,
#    'Nate': 0,
#    'Alex': 0,
#    'Brandon': 1}},
#  '633855': {'num_deaths': 5,
#   'num_characters': 6,
#   'character_deaths': {'Lt. Thomas W. Hart': 0,
#    'Col. William A. McNamara': 1,
#    'Lt. Lincoln A. Scott': 1,
#    'Lt. Lamar T. Archer': 1,
#    'Staff Sgt. Vic W. Bedford': 1,
#    'Col. Werner Visser': 1}},
#  '29785': {'num_deaths': 5,
#   'num_characters': 11,
#   'character_deaths': {'FBI Director James Womack': 0,
#    'Dr. Stanley Goodspeed': 1,
#    'Carla Pestalozzi': 0,
#    'Special Agent Ernest Paxton': 0,
#    'Brigadier General Francis X. Hummel, USMC': 0,
#    'Commander Anderson': 0,
#    'Captain Frye': 1,
#    'Captain Darrow': 1,
#    'Sergeant Crisp': 1,
#    'Major Tom Baxter': 1,
#    'Marine Captain Hendrix': 0}},
#  '2667958': {'num_deaths': 5,
#   'num_characters': 10,
#   'character_deaths': {'Joey Pantucci': 0,
#    'T-Ray Jones': 0,
#    'Vivo': 0,
#    'Mason': 0,
#    'Mulligan': 1,
#    'Simon Canton': 1,
#    'Captain Atherton': 1,
#    'Trillian St. James': 1,
#    'Mamooli': 0,
#    'Hanover': 1}},
#  '2039953': {'num_deaths': 5,
#   'num_characters': 13,
#   'character_deaths': {'Uncle Charlie': 0,
#    'Tom': 0,
#    'Mr. Mehlor': 1,
#    'Kenny': 1,
#    'Ray': 1,
#    'Sheriff Mike Collins': 0,
#    'Wayne Bryce': 1,
#    'Phil': 0,
#    'Karen': 0,
#    'Hank': 0,
#    'Doreen Sears': 0,
#    'Henry Sears': 0,
#    'Jim': 1}},
#  '1673514': {'num_deaths': 5,
#   'num_characters': 7,
#   'character_deaths': {'Claude Banks': 1,
#    'Daisy': 0,
#    'Biscuit': 0,
#    'Dexter Wilkins': 1,
#    'Older Sheriff Pike': 1,
#    'Winston Hancock': 1,
#    'Willie Long': 1}},
#  '97646': {'num_deaths': 5,
#   'num_characters': 15,
#   'character_deaths': {'John McClane': 0,
#    'Holly Gennaro McClane': 0,
#    'Hans Gruber': 0,
#    'Franco': 1,
#    'Tony': 0,
#    'Theo': 0,
#    'Alexander': 0,
#    'Marco': 1,
#    'Uli': 1,
#    'Joseph Yoshinobu Takagi': 1,
#    'Sgt. Al Powell': 0,
#    'Harry Ellis': 1,
#    'Karl': 0,
#    'Richard Thornburg': 0,
#    'Argyle': 0}},
#  '161912': {'num_deaths': 5,
#   'num_characters': 8,
#   'character_deaths': {'Mattie Ross': 1,
#    'Tom Chaney': 0,
#    'Rooster Cogburn': 0,
#    'Ned Pepper': 1,
#    'La Boeuf': 1,
#    'Emmett Quincy': 1,
#    'Moon': 1,
#    'Lawyer Daggett': 0}},
#  '2002320': {'num_deaths': 5,
#   'num_characters': 8,
#   'character_deaths': {'Michael Myers': 1,
#    'Jamie Lloyd': 1,
#    'Samuel J. Loomis': 0,
#    'Sheriff Ben Meeker': 1,
#    'Rachel Carruthers': 1,
#    'Tina Williams': 0,
#    'Spitz': 1,
#    'Billy Hill': 0}},
#  '26717073': {'num_deaths': 5,
#   'num_characters': 8,
#   'character_deaths': {'Dr. Martin Harris': 1,
#    'Gina': 0,
#    'Rodney Cole': 1,
#    'Professor Leo Bressler': 1,
#    'Smith': 1,
#    'Nurse Gretchen Erfurt': 1,
#    'Prince Shada': 0,
#    'Jones': 0}},
#  '5292920': {'num_deaths': 5,
#   'num_characters': 10,
#   'character_deaths': {'Grigori Rasputin': 1,
#    'Ilsa Haupstein': 1,
#    'Karl Ruprecht Kroenen': 0,
#    'Trevor "Broom" Bruttenholm': 1,
#    'John Myers': 0,
#    'Hellboy': 1,
#    'Abe Sapien': 0,
#    'Liz Sherman': 0,
#    'Sammael': 1,
#    'Tom Manning': 0}},
#  '5795244': {'num_deaths': 5,
#   'num_characters': 7,
#   'character_deaths': {'Renzaburô Taki': 0,
#    'Daishu (Yuen Tai Chung)': 1,
#    'Shudo': 1,
#    'Windy (Gaye)': 1,
#    'Ken Kai': 1,
#    'Orchid': 1,
#    'Sergeant Kayama': 0}},
#  '357186': {'num_deaths': 4,
#   'num_characters': 8,
#   'character_deaths': {'Balian de Ibelin': 1,
#    'Godfrey de Ibelin': 1,
#    'Jerusalem': 1,
#    'King Baldwin': 1,
#    'Sibylla': 0,
#    'Guy de Lusignan': 0,
#    'Saladin': 0,
#    'Tiberias': 0}},
#  '957359': {'num_deaths': 4,
#   'num_characters': 9,
#   'character_deaths': {"Alex O'Connell": 1,
#    'High Priest Imhotep': 0,
#    'Baltus Hafez': 1,
#    'Meela Nais': 0,
#    'Ardeth Bay': 0,
#    'Izzy Buttons': 0,
#    "Evelyn Carnahan-O'Connell": 1,
#    'Lock-Nah': 1,
#    'Jonathan Carnahan': 0}},
#  '797798': {'num_deaths': 4,
#   'num_characters': 11,
#   'character_deaths': {'Alice': 0,
#    'Jill Valentine': 0,
#    'Major Timothy Cain': 0,
#    'Carlos Olivera': 0,
#    'Terri Morales': 1,
#    'Matt Addison': 0,
#    'L.J.': 0,
#    'Nemesis': 1,
#    'Nicholai Ginovaeff': 1,
#    'Dr. Ashford': 1,
#    'Dr. Sam Isaacs': 0}},
#  '19761638': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Don McKay': 1,
#    'Sonny': 0,
#    'Samuel': 0,
#    'Marie': 1,
#    'Dr. Lance Pryce': 1,
#    'Otis Kent': 0,
#    'Mel': 1}},
#  '732851': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Lt. Chris Burnett': 1,
#    'Stackhouse': 1,
#    'Miroslav Lokar': 0,
#    'Sasha': 1,
#    'Bazda': 1,
#    'Admiral Leslie McMahon Reigart': 0,
#    'Admiral Piquet': 0}},
#  '5018573': {'num_deaths': 4,
#   'num_characters': 6,
#   'character_deaths': {'Jud Crandall': 1,
#    'Louis Creed': 1,
#    'Victor Pascow': 1,
#    'Ellie Creed': 0,
#    'Rachel Creed': 0,
#    'Gage Creed': 1}},
#  '1243901': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Arthur': 0,
#    'George': 0,
#    'Kate': 0,
#    'Guy': 1,
#    'Jimmy': 1,
#    'Mandy': 1,
#    'Craig': 1}},
#  '23576946': {'num_deaths': 4,
#   'num_characters': 8,
#   'character_deaths': {'Arkin': 1,
#    'Michael Chase': 1,
#    'Victoria Chase': 0,
#    'Jill Chase': 0,
#    'Hannah Chase': 0,
#    'Larry Wharton': 0,
#    'The Collector': 1,
#    'Chad': 1}},
#  '2912982': {'num_deaths': 4,
#   'num_characters': 10,
#   'character_deaths': {'Charlie Burns': 1,
#    'Captain Stanley': 0,
#    'Arthur Burns': 1,
#    'Martha Stanley': 0,
#    'Eden Fletcher': 0,
#    'Sergeant Lawrence': 1,
#    'Jacko': 1,
#    'Jellon Lamb': 0,
#    'Samuel Stoat': 0,
#    'Queenie': 0}},
#  '284676': {'num_deaths': 4,
#   'num_characters': 6,
#   'character_deaths': {'Brett McBain': 1,
#    'Morton': 1,
#    'Frank': 1,
#    'Cheyenne': 0,
#    'Jill McBain': 1,
#    'Harmonica': 0}},
#  '2253390': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Juno': 0,
#    'Sarah': 0,
#    'Beth': 1,
#    'Paul': 1,
#    'Sam': 1,
#    'Rebecca': 1,
#    'Holly': 0}},
#  '157481': {'num_deaths': 4,
#   'num_characters': 11,
#   'character_deaths': {'James Bond': 1,
#    'Ernst Stavro Blofeld': 1,
#    'Mr. Wint': 0,
#    'Mr. Kidd': 0,
#    'Tiffany Case': 0,
#    'Felix Leiter': 0,
#    'Shady Tree': 1,
#    'Willard Whyte': 0,
#    "Plenty O'Toole": 1,
#    'Bert Saxby': 0,
#    'Dr. Metz': 0}},
#  '62668': {'num_deaths': 4,
#   'num_characters': 10,
#   'character_deaths': {'Katie Embry': 1,
#    'Becca Kotler': 0,
#    'Aidan Keller': 0,
#    'Ruth Embry': 0,
#    'Rachel Keller': 1,
#    'Noah Clay': 1,
#    'Anna Morgan': 1,
#    'Richard Morgan': 0,
#    'Samara Morgan': 0,
#    'Dr. Grasnik': 0}},
#  '1129847': {'num_deaths': 4,
#   'num_characters': 9,
#   'character_deaths': {'Matt Murdock': 0,
#    'Foggy Nelson': 0,
#    'Daredevil': 1,
#    'Elektra Natchios': 1,
#    'Nikolas Natchios': 1,
#    'Kingpin': 0,
#    'Bullseye': 1,
#    'Ben Urich': 0,
#    'Father Everett': 0}},
#  '11242': {'num_deaths': 4,
#   'num_characters': 6,
#   'character_deaths': {'Doctor Aki Ross': 0,
#    'Captain Gray Edwards': 0,
#    'General Hein': 1,
#    'Ryan': 1,
#    'Neil': 1,
#    'Jane': 1}},
#  '27731736': {'num_deaths': 4,
#   'num_characters': 10,
#   'character_deaths': {'Valerie': 0,
#    'Cesaire': 0,
#    'Suzette': 0,
#    'Father Solomon': 1,
#    'Henry': 0,
#    'Captain': 0,
#    'Claude': 0,
#    'Roxanne': 1,
#    'Father Auguste': 1,
#    'Grandmother': 1}},
#  '5078515': {'num_deaths': 4,
#   'num_characters': 8,
#   'character_deaths': {'James Bond': 1,
#    'Aki': 1,
#    'Tiger Tanaka': 0,
#    'Henderson': 1,
#    'Mr. Osato': 1,
#    'Helga Brandt': 0,
#    'Ernst Stavro Blofeld': 0,
#    'Kissy Suzuki': 0}},
#  '37599': {'num_deaths': 4,
#   'num_characters': 8,
#   'character_deaths': {'Montel Gordon': 0,
#    'Ray Castro': 1,
#    'Eduardo Ruiz': 1,
#    'Carlos Ayala': 0,
#    'Robert Wakefield': 0,
#    'Helena Ayala': 0,
#    'Francisco Flores': 1,
#    'General Arturo Salazar': 1}},
#  '3635829': {'num_deaths': 4,
#   'num_characters': 11,
#   'character_deaths': {'Joey Gazelle': 1,
#    "Tommy 'Tombs' Perello": 0,
#    'Nicky Gazelle': 0,
#    'Oleg Yugorsky': 1,
#    'Mila Yugorsky': 1,
#    'Anzor Yugorsky': 1,
#    'Lester the Pimp': 0,
#    'Divina': 0,
#    'Frankie Perello': 0,
#    'Edele': 0,
#    'Teresa Gazelle': 0}},
#  '30928961': {'num_deaths': 4,
#   'num_characters': 6,
#   'character_deaths': {'Abraham Lincoln': 0,
#    'Nancy Hanks Lincoln': 1,
#    'William Johnson': 1,
#    'Adam': 1,
#    'Joshua Speed': 1,
#    'Mary Todd Lincoln': 0}},
#  '267848': {'num_deaths': 4,
#   'num_characters': 9,
#   'character_deaths': {'Tony Montana': 1,
#    'Manny Ribera': 1,
#    'Frank Lopez': 0,
#    'Omar Suarez': 0,
#    'Angel': 1,
#    'Elvira Hancock': 0,
#    'Gina Montana': 0,
#    'Mel Bernstein': 1,
#    'Alberto The Shadow': 0}},
#  '23992760': {'num_deaths': 4,
#   'num_characters': 9,
#   'character_deaths': {'Dr. Abigail Tyler': 1,
#    'Sheriff August': 1,
#    'Will Tyler': 1,
#    'Ashley Tyler': 0,
#    'Ronnie Tyler': 0,
#    'Tommy Fisher': 1,
#    'Abbey Tyler': 0,
#    'Abel Campos': 0,
#    'Awolowa Odusami': 0}},
#  '1849258': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Carly Jones': 1,
#    'Wade': 1,
#    'Paige Edwards': 0,
#    'Dalton Chapman': 0,
#    'Nick Jones': 0,
#    'Vincent Sinclair': 1,
#    'Blake': 1}},
#  '11040532': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Kumar': 0,
#    'Meena Verma': 1,
#    'Police Inspector Ashok': 0,
#    'Captain Rajesh': 1,
#    'Sarika': 1,
#    'Mrs. Tejpal': 1,
#    'Shabnam': 0}},
#  '518928': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Mort Rainey': 1,
#    'Amy Rainey': 0,
#    'John Shooter': 0,
#    'Sheriff Dave Newsome': 0,
#    'Ted Milner': 1,
#    'Ken Karsch': 1,
#    'Tom Greenleaf': 1}},
#  '16718585': {'num_deaths': 4,
#   'num_characters': 10,
#   'character_deaths': {'Ty Hackett': 1,
#    'Ashcroft': 0,
#    'Mike Cochrane': 0,
#    'Jimmy Hackett': 0,
#    'Baines': 1,
#    'Eckehart': 0,
#    'Dobbs': 0,
#    'Palmer': 1,
#    'Quinn': 1,
#    'Joe the Cook': 0}},
#  '23982633': {'num_deaths': 4,
#   'num_characters': 13,
#   'character_deaths': {'Leonard Attwell': 1,
#    'Harry Brown': 0,
#    'D.I. Alice Frampton': 0,
#    'D.S. Terry Hicock': 0,
#    'Noel Winters': 0,
#    'Dean Saunders': 1,
#    'Kenny': 0,
#    'Stretch': 0,
#    'Marky': 1,
#    'Troy Martindale': 0,
#    'Carl': 1,
#    'S.I. Childs': 0,
#    'Sid Rourke': 0}},
#  '28882162': {'num_deaths': 4,
#   'num_characters': 8,
#   'character_deaths': {'Judge Dredd': 1,
#    'Chief Judge': 0,
#    'Cassandra Anderson': 1,
#    "Madeline 'Ma-Ma' Madrigal": 0,
#    'Kay': 1,
#    'Judge Chan': 1,
#    'Judge T.J. Alvarez': 0,
#    'Judge Lex': 0}},
#  '2920077': {'num_deaths': 4,
#   'num_characters': 8,
#   'character_deaths': {'Erik Lanshof': 1,
#    'Robby Froost': 0,
#    'Esther': 0,
#    'Colonel Rafelli': 0,
#    'Susan': 0,
#    'Guus LeJeune': 1,
#    'Jan Weinberg': 1,
#    'Alex': 1}},
#  '8432450': {'num_deaths': 4,
#   'num_characters': 11,
#   'character_deaths': {'David Drayton': 1,
#    'Brent Norton': 0,
#    'Dan Miller': 0,
#    'Mrs. Carmody': 0,
#    'Norm': 0,
#    'Ollie Weeks': 1,
#    'Private Jessup': 1,
#    'Jim': 0,
#    'Ambrose Cornell': 1,
#    'Amanda Dunfrey': 0,
#    'Irene Reppler': 0}},
#  '3616797': {'num_deaths': 4,
#   'num_characters': 12,
#   'character_deaths': {'Maximus Decimus Meridius': 1,
#    'Marcus Aurelius': 0,
#    'Commodus': 1,
#    'Quintus': 0,
#    'Proximo': 1,
#    'Hagen': 1,
#    'Juba': 0,
#    'Tigris': 0,
#    'Cicero': 0,
#    'Gracchus': 0,
#    'Lucius Verus': 0,
#    'Lucilla': 0}},
#  '30273553': {'num_deaths': 4,
#   'num_characters': 9,
#   'character_deaths': {'Driver': 1,
#    'Shannon': 0,
#    'Irene': 0,
#    'Bernie Rose': 1,
#    'Nino': 1,
#    'Benicio': 0,
#    'Standard': 0,
#    'Cook': 0,
#    'Blanche': 1}},
#  '3745527': {'num_deaths': 4,
#   'num_characters': 8,
#   'character_deaths': {'Adam': 0,
#    'Mike': 1,
#    'Derrick': 1,
#    'Allison': 1,
#    'Chelsea': 1,
#    'Jake': 0,
#    'The Host': 0,
#    'Pinhead': 0}},
#  '2837025': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Christine York': 1,
#    'Mabel': 0,
#    'Jericho Cane': 1,
#    'The Man / Satan': 1,
#    'Bobby Chicago': 1,
#    'Thomas Aquinas': 0,
#    'Father Kovak': 0}},
#  '19596597': {'num_deaths': 4,
#   'num_characters': 9,
#   'character_deaths': {'Sherlock Holmes': 1,
#    'Lord Blackwood': 1,
#    'Inspector Lestrade': 0,
#    'Doctor Watson': 0,
#    'Mary Morstan': 0,
#    'Irene Adler': 0,
#    'Lord Coward': 0,
#    'Sir Thomas': 1,
#    'John Standish': 1}},
#  '724258': {'num_deaths': 4,
#   'num_characters': 11,
#   'character_deaths': {'Ethan Hunt': 0,
#    'Jim Phelps': 0,
#    'Alexander Golitsyn': 1,
#    'Jack Harmon': 0,
#    'Hannah Williams': 1,
#    'Sarah Davies': 1,
#    'Franz Krieger': 0,
#    'Agent Eugene Kittridge': 0,
#    'Max': 0,
#    'Claire Phelps': 1,
#    'Luther Stickell': 0}},
#  '50744': {'num_deaths': 4,
#   'num_characters': 10,
#   'character_deaths': {'Luke Skywalker': 1,
#    'Han Solo': 1,
#    'Leia Organa': 0,
#    'C-3PO': 0,
#    'R2-D2': 0,
#    'Boba Fett': 0,
#    'Yoda': 1,
#    'Darth Vader': 1,
#    'Obi-Wan Kenobi': 0,
#    'Anakin Skywalker': 0}},
#  '2680994': {'num_deaths': 4,
#   'num_characters': 6,
#   'character_deaths': {'Ricky Caldwell': 1,
#    'Dr. Henry Bloom': 1,
#    'Chip': 1,
#    'Jennifer': 0,
#    'Mother Superior': 1,
#    'Sister Mary': 0}},
#  '5526916': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Jack Chen': 1,
#    'Fiona Birch': 0,
#    'Madam M': 1,
#    'Charlene Ching': 0,
#    'Jing': 1,
#    'Faye Ching': 0,
#    'Ryuichi': 1}},
#  '982480': {'num_deaths': 4,
#   'num_characters': 9,
#   'character_deaths': {'Dejah Thoris': 1,
#    'Edgar Rice Burroughs': 1,
#    'Powell': 0,
#    'Tars Tarkas': 0,
#    'Sab Than': 1,
#    'Matai Shang': 0,
#    'John Carter': 0,
#    'Sola': 0,
#    'Tal Hajus': 1}},
#  '1083768': {'num_deaths': 4,
#   'num_characters': 9,
#   'character_deaths': {'Jake Harris': 0,
#    'Bobby Whitman': 0,
#    'Vince Sherman': 0,
#    'Nicole Willis': 0,
#    'Sara Moore': 1,
#    'Gabe Jensen': 0,
#    'J.D. Reston': 1,
#    'Rafe Perry': 1,
#    'Lucas Harper': 1}},
#  '31186339': {'num_deaths': 4,
#   'num_characters': 13,
#   'character_deaths': {'Primrose Everdeen': 0,
#    'Peeta Mellark': 0,
#    'Katniss Everdeen': 0,
#    'Haymitch Abernathy': 0,
#    'Caesar Flickerman': 0,
#    'Rue': 1,
#    'Cato': 0,
#    'Marvel': 0,
#    'Seneca Crane': 0,
#    'Clove': 1,
#    'Thresh': 1,
#    'Foxface': 1,
#    'President Snow': 0}},
#  '2282187': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Thomas Dagget': 0,
#    'Simon': 1,
#    'Gabriel': 1,
#    'Jerry': 1,
#    'Mary': 0,
#    'Katherine': 0,
#    'Rachael': 1}},
#  '21870282': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Owen Lansing': 1,
#    'Cameron': 1,
#    'Dory Lansing': 0,
#    'Bob Froelich': 1,
#    'Pete Groom': 0,
#    'Nora Haley': 0,
#    'Ben Majors': 1}},
#  '2706589': {'num_deaths': 4,
#   'num_characters': 8,
#   'character_deaths': {'Lee Blanchard': 1,
#    'Elizabeth Short': 1,
#    'Lorna Mertz': 0,
#    'Madeleine Linscott': 1,
#    'Kay Lake': 0,
#    'Emmett Linscott': 1,
#    'Ramona Linscott': 0,
#    'Martha Linscott': 0}},
#  '14725310': {'num_deaths': 4,
#   'num_characters': 11,
#   'character_deaths': {'Saigo': 0,
#    'Kashiwara': 0,
#    'Captain Tanida': 1,
#    'General Kuribayashi': 0,
#    'Baron Nishi': 1,
#    'Shimizu': 1,
#    'Colonel Adachi': 0,
#    'Lieutenant Ito': 0,
#    'Lieutenant Okubo': 0,
#    'Sam': 0,
#    'Lieutenant Fujita': 1}},
#  '4738713': {'num_deaths': 4,
#   'num_characters': 14,
#   'character_deaths': {'Linnet Ridgeway Doyle': 1,
#    'Jacqueline De Bellefort': 1,
#    'Simon Doyle': 0,
#    'Manager of The Karnak': 0,
#    'Hercule Poirot': 0,
#    'Marie Van Schuyler': 0,
#    'Miss Bowers': 0,
#    'Louise Bourget': 1,
#    'James Ferguson': 0,
#    'Salome Otterbourne': 1,
#    'Rosalie Otterbourne': 0,
#    'Andrew Pennington': 0,
#    'Doctor Ludwig Bessner': 0,
#    'Colonel Johnny Race': 0}},
#  '1695219': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Peter Garrett': 0,
#    'Royce Garrett': 0,
#    'Annie Garrett': 0,
#    'Elliot Vaughn': 1,
#    'Tom McLaren': 1,
#    'Monique Aubertine': 1,
#    'Cyril Bench': 1}},
#  '481649': {'num_deaths': 4,
#   'num_characters': 6,
#   'character_deaths': {'Lieutenant Nilsen': 1,
#    'Nick Curran': 1,
#    'Catherine Tramell': 1,
#    'Gus': 1,
#    'Dr. Beth Garner': 0,
#    'Hazel Dobkins': 0}},
#  '7583011': {'num_deaths': 4,
#   'num_characters': 6,
#   'character_deaths': {'Jay': 1,
#    'Orin Kiefer': 0,
#    'Peter': 1,
#    'Sleeper': 0,
#    'Holly': 1,
#    'Bug': 1}},
#  '73875': {'num_deaths': 4,
#   'num_characters': 14,
#   'character_deaths': {'Don Ciccio': 1,
#    'Vito Corleone': 0,
#    'Pat Geary': 0,
#    'Johnny Ola': 0,
#    'Michael Corleone': 1,
#    'Hyman Roth': 1,
#    'Frank Pentangeli': 0,
#    'Tom Hagen': 0,
#    'Young Clemenza': 0,
#    'Fredo Corleone': 0,
#    'Al Neri': 0,
#    'Kay Adams': 0,
#    'Connie Corleone': 0,
#    'Rocco Lampone': 1}},
#  '18774910': {'num_deaths': 4,
#   'num_characters': 6,
#   'character_deaths': {'Payton': 1,
#    'Bower': 1,
#    'Nadia': 0,
#    'Manh': 1,
#    'Gallo': 0,
#    'Leland': 1}},
#  '1976777': {'num_deaths': 4,
#   'num_characters': 9,
#   'character_deaths': {'Hannibal Lecter': 1,
#    'Mischa Lecter': 1,
#    'Lady Murasaki': 0,
#    'Inspector Popil': 0,
#    'Enrikas Dortlich': 1,
#    'Petras Kolnas': 0,
#    'Vladis Grutas': 1,
#    'Zigmas Milko': 0,
#    'Bronys Grentz': 0}},
#  '673613': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Detective Mike Lowrey': 1,
#    'Fouchet': 1,
#    'Julie Mott': 1,
#    'Captain Howard Eddie': 0,
#    'Jojo': 0,
#    'Noah Trafficante': 1,
#    'Marcus Burnett': 0}},
#  '26545312': {'num_deaths': 4,
#   'num_characters': 12,
#   'character_deaths': {'Marybeth': 0,
#    'Victor Crowley': 1,
#    'Jack Cracker': 1,
#    'Rev. Zombie': 0,
#    'Thomas Crowley': 1,
#    'Justin': 0,
#    'Bob': 1,
#    'Chad': 0,
#    'Layton': 0,
#    'Avery': 0,
#    'John': 0,
#    'Vernon': 0}},
#  '1469695': {'num_deaths': 4,
#   'num_characters': 6,
#   'character_deaths': {'Jessica': 1,
#    'Tim': 1,
#    "Tim's Mother": 1,
#    'Kate Houghton': 0,
#    'Franny Roberts': 0,
#    'Uncle Mike': 1}},
#  '6003182': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Dr. Iqbal Ansari': 1,
#    'Yashwant Angre': 1,
#    'Sr. Inspector Shekhar Verma': 1,
#    'Sub Inspector Ashwin Gupte': 0,
#    'Constable Kamlesh Sawant': 1,
#    'Minister Deodhar': 0,
#    'ACP Naidu': 0}},
#  '4131876': {'num_deaths': 4,
#   'num_characters': 8,
#   'character_deaths': {'Deathmask': 0,
#    'Hideous Dancer': 0,
#    'Cassie': 0,
#    'Sean': 1,
#    'Annabel': 1,
#    'Matt': 1,
#    'Father Jude': 1,
#    'Raven': 0}},
#  '15938122': {'num_deaths': 4,
#   'num_characters': 5,
#   'character_deaths': {'Solomon Kane': 1,
#    'Malachi': 1,
#    'Meredith Crowthorn': 1,
#    'Samuel Crowthorn': 0,
#    'William Crowthorn': 1}},
#  '5866831': {'num_deaths': 4,
#   'num_characters': 8,
#   'character_deaths': {'Prince Dastan': 1,
#    'King Sharaman': 0,
#    'Nizam': 1,
#    'Tamina': 0,
#    'Tus': 1,
#    'Garsiv': 1,
#    'Sheik Amar': 0,
#    'Seso': 0}},
#  '1667210': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Thor Carlsson': 0,
#    'Patricia Farren': 1,
#    'Dorothy Carlsson': 1,
#    'Jonathan Corliss': 1,
#    'Ellen Carlsson': 1,
#    'Jay Farraday': 0,
#    'Tommy Roussell': 0}},
#  '2130880': {'num_deaths': 4,
#   'num_characters': 9,
#   'character_deaths': {'Det. Tom Hardy': 1,
#    'Det. Jimmy Detillo': 1,
#    'Lt. Vince Hardy': 1,
#    'Det. Danny Detillo': 0,
#    'Chick Chicanis': 0,
#    'Jo Christman': 0,
#    'Dist. Atty. Frank Morris': 0,
#    'Det. Eddie Eiler': 0,
#    'Capt. Nick Detillo': 1}},
#  '16055802': {'num_deaths': 4,
#   'num_characters': 5,
#   'character_deaths': {'Tom Hanniger': 1,
#    'Axel Palmer': 0,
#    'Irene': 1,
#    'Megan': 1,
#    'Ben Foley': 1}},
#  '491757': {'num_deaths': 4,
#   'num_characters': 6,
#   'character_deaths': {'Dr. Carmack': 1,
#    'Sarge': 1,
#    'John "Reaper"" Grimm"': 0,
#    'Dr. Samantha Grimm': 0,
#    'Pinky': 1,
#    'Duke': 1}},
#  '27872044': {'num_deaths': 4,
#   'num_characters': 8,
#   'character_deaths': {'Kyle Miller': 1,
#    'Sarah Miller': 1,
#    'Avery Miller': 0,
#    'Elias': 1,
#    'Ty': 0,
#    'Jonah': 1,
#    'Petal': 0,
#    'Jake': 0}},
#  '4954774': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Julius Caesar': 0,
#    'Cleopatra': 1,
#    'Apollodorus': 0,
#    'Brutus': 1,
#    'Mark Antony': 1,
#    'Agrippa': 0,
#    'Rufio': 1}},
#  '1024501': {'num_deaths': 4,
#   'num_characters': 8,
#   'character_deaths': {'Malak': 0,
#    'Conan the Barbarian': 1,
#    'Queen Taramis': 1,
#    'Princess Jehnna': 1,
#    'Bombaata': 0,
#    "Akiro 'The Wizard'": 0,
#    'Zula': 0,
#    'Grand Vizier': 1}},
#  '7255312': {'num_deaths': 4,
#   'num_characters': 8,
#   'character_deaths': {'Ben Talbot': 1,
#    'Gwen Conliffe': 0,
#    'Lawrence Stewart Talbot': 1,
#    'Sir John Talbot': 1,
#    'Gypsy mother': 1,
#    'Solana Talbot': 0,
#    'Maleva': 0,
#    'Singh': 0}},
#  '67442': {'num_deaths': 4,
#   'num_characters': 8,
#   'character_deaths': {'Orin Boyd': 1,
#    'Frank Daniels': 1,
#    'Annette Mulcahy': 1,
#    'Latrell Walker': 0,
#    'T.K. Johnson': 0,
#    'Lewis Strutt': 1,
#    'George Clark': 0,
#    'Henry Wayne': 0}},
#  '1339563': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Lenny Nero': 1,
#    'Faith Justin': 1,
#    'Mace Mason': 0,
#    'Max Peltier': 1,
#    'Philo Gant': 0,
#    'Jeriko One': 0,
#    'Dwayne Engelman': 1}},
#  '534792': {'num_deaths': 4,
#   'num_characters': 7,
#   'character_deaths': {'Mike Norris': 0,
#    'Charles Lee Ray': 1,
#    'Andy Barclay': 1,
#    'Karen Barclay': 0,
#    'Maggie Peterson': 1,
#    'Jack Santos': 0,
#    'Dr. Ardmore': 1}},
#  '304692': {'num_deaths': 4,
#   'num_characters': 13,
#   'character_deaths': {'Shuya Nanahara': 0,
#    'Noriko Nakagawa': 0,
#    'Yoshitoki Kuninobu': 0,
#    'Fumiyo Fujiyoshi': 1,
#    'Kazuo Kiriyama': 0,
#    'Mitsuko Souma': 1,
# ...
#   'num_characters': 10,
#   'character_deaths': {'Michael McCrea': 0,
#    'Darren Perrier': 0,
#    'Brenda': 0,
#    'Shamie': 0,
#    'Jim McCrea': 1,
#    'Grim Reaper': 0,
#    'Jerome': 0,
#    'Clifford': 1,
#    'Blaise': 0,
#    'Victor': 0}},
#  '1939585': {'num_deaths': 2,
#   'num_characters': 10,
#   'character_deaths': {'Mona Dearly': 1,
#    'Clarence': 0,
#    'Chief Wyatt Rash': 0,
#    'Phil Dearly': 1,
#    'Jeff Dearly': 0,
#    'Bobby Calzone': 0,
#    'Rona Mace': 0,
#    'Murph Calzone': 0,
#    'Lucinda': 0,
#    'Valerie Antonielli': 0}},
#  '1679809': {'num_deaths': 2,
#   'num_characters': 5,
#   'character_deaths': {'Karan Kapoor': 0,
#    'Rhea Prakash': 1,
#    'Sameer': 1,
#    'Mihir Vora': 0,
#    'Diana Fernandez': 0}},
#  '226682': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Eriksson': 1,
#    'Sgt. Tony Meserve': 1,
#    'PFC Antonio Diaz': 0,
#    'PFC Herbert Hatcher': 0}},
#  '25737142': {'num_deaths': 2,
#   'num_characters': 7,
#   'character_deaths': {'Spencer Aimes': 1,
#    'Jen Kornfeldt': 0,
#    'Holbrook': 0,
#    'Mr. Kornfeldt': 0,
#    'Henry': 0,
#    'Olivia Brooks': 1,
#    'Kristen': 0}},
#  '5483227': {'num_deaths': 2,
#   'num_characters': 5,
#   'character_deaths': {'Marva Munson': 1,
#    'Professor G.H. Dorr': 1,
#    'Lump Hudson': 0,
#    'The General': 0,
#    'Garth Pancake': 0}},
#  '6475757': {'num_deaths': 2,
#   'num_characters': 6,
#   'character_deaths': {'Ravi Verma': 1,
#    'Sir Judah': 0,
#    'Kamini Verma': 0,
#    'Monty Oberoi': 1,
#    'Tina': 0,
#    'Kabira': 0}},
#  '19463174': {'num_deaths': 2,
#   'num_characters': 3,
#   'character_deaths': {'Disha': 1, 'Amar Khanna': 0, 'Sunita Menon': 1}},
#  '3598984': {'num_deaths': 2,
#   'num_characters': 5,
#   'character_deaths': {'Justin Quayle': 1,
#    'Tessa Quayle': 1,
#    'Dr. Arnold Bluhm': 0,
#    'Sandy Woodrow': 0,
#    'Sir Bernard Pellegrin': 0}},
#  '5778040': {'num_deaths': 2,
#   'num_characters': 8,
#   'character_deaths': {'Bela Makhija': 0,
#    'Pappu Master': 0,
#    'Shanti Priya': 1,
#    "Mukesh 'Mike' Mehra": 1,
#    'Mrs. Rajesh Kapoor': 0,
#    'Om Prakash': 0,
#    'Om Kapoor': 0,
#    'Sandy': 0}},
#  '5676296': {'num_deaths': 2,
#   'num_characters': 2,
#   'character_deaths': {'Liberty Wallace': 1, 'Joe': 1}},
#  '21762864': {'num_deaths': 2,
#   'num_characters': 6,
#   'character_deaths': {'Rachel Singer': 0,
#    'Vogel': 1,
#    'David': 1,
#    'Stefan': 0,
#    'Mossad Agent': 0,
#    'Sarah': 0}},
#  '20198389': {'num_deaths': 2,
#   'num_characters': 2,
#   'character_deaths': {'Sam': 1, 'Malestrazza': 1}},
#  '250012': {'num_deaths': 2,
#   'num_characters': 9,
#   'character_deaths': {'Megan Wheeler': 0,
#    'Sarah Wheeler': 0,
#    'Hull Barret': 0,
#    'Preacher': 1,
#    'Coy LaHood': 1,
#    'Josh LaHood': 0,
#    'Club': 0,
#    'Stockburn': 0,
#    'Spider Conway': 0}},
#  '31879136': {'num_deaths': 2,
#   'num_characters': 13,
#   'character_deaths': {'Clayton': 0,
#    'Mo': 0,
#    'Maddy': 0,
#    'Chet': 1,
#    'Kyle': 1,
#    'Barry': 0,
#    'Ashley': 0,
#    'Shelby': 0,
#    'Josh': 0,
#    'Travis': 0,
#    'Mr. Goodman': 0,
#    'Andrew Cunningham': 0,
#    'Big Dave': 0}},
#  '241603': {'num_deaths': 2,
#   'num_characters': 10,
#   'character_deaths': {'Austin Powers': 1,
#    'Vanessa Kensington': 0,
#    'Mini-Me': 0,
#    'Young Number Two': 0,
#    'Frau Farbissina': 0,
#    'Fat Bastard': 0,
#    'Ivana Humpalot': 0,
#    'Felicity Shagwell': 1,
#    'Mustafa': 0,
#    'Scott Evil': 0}},
#  '11698816': {'num_deaths': 2,
#   'num_characters': 2,
#   'character_deaths': {'Emily Nicholson': 1, 'Resse Nicholson': 1}},
#  '8360654': {'num_deaths': 2,
#   'num_characters': 7,
#   'character_deaths': {'Randy Daytona': 0,
#    'Karl Wolfschtagg': 1,
#    'Feng': 0,
#    'Rodriguez': 0,
#    'Wong': 0,
#    'Maggie': 1,
#    'Mahogany': 0}},
#  '2900798': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Captain Mike Turner': 1,
#    'Celeste Whitman': 0,
#    'Captain Stefan Svevo': 1,
#    'Nurse Gina Rowe': 0}},
#  '6646087': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Lew Harper': 1,
#    'Susan Harper': 0,
#    'Mrs. Sampson': 1,
#    'Allan Taggert': 0}},
#  '1202791': {'num_deaths': 2,
#   'num_characters': 7,
#   'character_deaths': {'Simon Fletcher': 0,
#    'Paul Fletcher': 1,
#    'Frances Fletcher': 0,
#    'Aunt Nina Fletcher': 0,
#    'Jay Corgan': 1,
#    'Robin Childers': 0,
#    'Denise Gilmore': 0}},
#  '15233369': {'num_deaths': 2,
#   'num_characters': 7,
#   'character_deaths': {'Jamal Malik': 0,
#    'Salim Malik': 0,
#    'Latika': 0,
#    'Amitabh Bachchan': 0,
#    'Maman': 1,
#    'Javed': 1,
#    'Prem Kumar': 0}},
#  '67417': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Casey Ryback': 0,
#    'Cmdr. Krill': 1,
#    'Jordan Tate': 0,
#    'Capt. Adams': 1}},
#  '13875263': {'num_deaths': 2,
#   'num_characters': 13,
#   'character_deaths': {'Sam': 1,
#    'Claire': 0,
#    'Hayden': 0,
#    'Lexi': 0,
#    'Moony': 0,
#    'Jay': 1,
#    'Andreas': 0,
#    'Dabs': 0,
#    'Henry': 0,
#    'Blammy': 0,
#    'Omen': 0,
#    'Uncle Curtis': 0,
#    'Ike': 0}},
#  '1612686': {'num_deaths': 2,
#   'num_characters': 10,
#   'character_deaths': {'Laurie Strode': 0,
#    'Michael Myers': 1,
#    'Rudy': 0,
#    'Sara Moyer': 0,
#    'Freddie Harris': 0,
#    'Nora Winston': 0,
#    'Myles Barton': 0,
#    'Bill': 0,
#    'Donna': 0,
#    'Jen': 1}},
#  '10962872': {'num_deaths': 2,
#   'num_characters': 5,
#   'character_deaths': {'Dr. Satyajit Chavan': 1,
#    'Sarabjeet Singh': 0,
#    'Kashmira': 0,
#    'Priya Patel': 0,
#    'David Abraham': 1}},
#  '10417568': {'num_deaths': 2,
#   'num_characters': 5,
#   'character_deaths': {'Harry Burck Jr.': 0,
#    'Spence': 0,
#    'Washington aide': 0,
#    'Jack': 1,
#    'Norman Shrike': 1}},
#  '13253566': {'num_deaths': 2,
#   'num_characters': 7,
#   'character_deaths': {'Danny': 0,
#    'Anson Wheeler': 0,
#    'Beth': 0,
#    'Gayle Sweeney': 0,
#    'Ronnie Shields': 1,
#    'Augie Farks': 1,
#    'King Argotron': 0}},
#  '5271413': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Van Sant': 1, 'Antoine': 0, 'Lena': 1, 'Michelle': 0}},
#  '12002': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Miki Saegusa': 0,
#    'Godzilla': 1,
#    'Businessman Yasuaki Shindo': 1,
#    'Emmy Kano': 0}},
#  '3210303': {'num_deaths': 2,
#   'num_characters': 7,
#   'character_deaths': {'Howard Campbell': 1,
#    'Major Frank Wirtanen': 0,
#    'Joseph Goebbels': 0,
#    'Helga Noth / Resi Noth': 1,
#    'Dr. Abraham Epstein': 0,
#    'George Kraft': 0,
#    'Adolf Eichmann': 0}},
#  '3027347': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Ryan Gaerity': 1,
#    'James Dove': 0,
#    "Max O'Bannon": 1,
#    'Anthony Franklin': 0}},
#  '144161': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Jerry Fletcher': 1,
#    'Alice Sutton': 0,
#    'Dr. Jonas': 1,
#    'Agent Lowry': 0}},
#  '1094668': {'num_deaths': 2,
#   'num_characters': 7,
#   'character_deaths': {'Emperor Chadragupta': 0,
#    'Asoka': 0,
#    'Susima': 1,
#    'Dharma': 1,
#    'Kaurwaki': 0,
#    'King Bindusara': 0,
#    'Devi': 0}},
#  '30714098': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Will Shaw': 0, 'Martin': 1, 'Lucia': 0, 'Gorman': 1}},
#  '1048695': {'num_deaths': 2,
#   'num_characters': 6,
#   'character_deaths': {'Count Dracula': 1,
#    'Abraham Van Helsing': 1,
#    'John Seward': 0,
#    'Lucy Westenra': 0,
#    'Jonathan Harker': 0,
#    'Mina Harker': 0}},
#  '8821816': {'num_deaths': 2,
#   'num_characters': 6,
#   'character_deaths': {'Annabelle': 0,
#    'Carface Carruthers': 1,
#    'Charlie B. Barkin': 0,
#    'Itchy Itchiford': 0,
#    'Killer': 1,
#    'Belladonna': 0}},
#  '2614244': {'num_deaths': 2,
#   'num_characters': 3,
#   'character_deaths': {'CBI Officer Reet Oberoi': 1,
#    'Lajja Shankar Pandey': 1,
#    'Professor Aman Varma': 0}},
#  '17867578': {'num_deaths': 2,
#   'num_characters': 3,
#   'character_deaths': {'Karthik': 0, 'Sandhya': 1, 'Gheetha': 1}},
#  '30000': {'num_deaths': 2,
#   'num_characters': 7,
#   'character_deaths': {'Travis Bickle': 1,
#    'Betsy': 0,
#    'Tom': 0,
#    'Wizard': 0,
#    'Iris': 0,
#    "Matthew 'Sport' Higgins": 0,
#    'Charles Palantine': 1}},
#  '2045991': {'num_deaths': 2,
#   'num_characters': 8,
#   'character_deaths': {'Samantha Albertson': 0,
#    'Dr. Roberta Martin': 1,
#    'Chrissy DeWitt Williams': 0,
#    "Tina 'Teeny' Tercell": 0,
#    'Teeny': 1,
#    'Bud Kent': 0,
#    'Scott Wormer': 0,
#    'Crazy Pete': 0}},
#  '3499096': {'num_deaths': 2,
#   'num_characters': 5,
#   'character_deaths': {'Jack Ryan': 0,
#    'Lord William Holmes': 0,
#    'Sean Miller': 1,
#    "Kevin O'Donnell": 1,
#    'Adm. James Greer': 0}},
#  '1152416': {'num_deaths': 2,
#   'num_characters': 5,
#   'character_deaths': {'Milo Hoffman': 1,
#    'Gary Winston': 0,
#    'Alice Poulson': 0,
#    'Teddy Chin': 1,
#    'Lisa Calighan': 0}},
#  '34383775': {'num_deaths': 2,
#   'num_characters': 2,
#   'character_deaths': {'Emily': 1, 'Corey': 1}},
#  '709510': {'num_deaths': 2,
#   'num_characters': 8,
#   'character_deaths': {'Arthur': 0,
#    'Merlin': 0,
#    'Marius Honorius': 0,
#    'Cerdic': 1,
#    'Cynric': 0,
#    'Guinevere': 0,
#    'Dagonet': 0,
#    'Lancelot': 1}},
#  '705925': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Joseph Donnelly': 1,
#    'Daniel Christie': 0,
#    'Stephen Chase': 1,
#    'Shannon Christie': 0}},
#  '17125190': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Arjun Malvankar': 1,
#    'Insp. Ravi Rane': 0,
#    'Geeta Sahani': 0,
#    'Chander': 1}},
#  '21655117': {'num_deaths': 2,
#   'num_characters': 5,
#   'character_deaths': {'ACP Agnel Wilson': 0,
#    'Shoaib Khan': 1,
#    'Sultan Mirza': 1,
#    'Rehana': 0,
#    'Mumtaz': 0}},
#  '16166559': {'num_deaths': 2,
#   'num_characters': 6,
#   'character_deaths': {'Phil Ramos': 1,
#    'Walter Garber': 1,
#    'Bernard Ryder': 0,
#    'Bashkim': 0,
#    'Jerry Pollard (Motorman)': 0,
#    'Camonetti': 0}},
#  '2275251': {'num_deaths': 2,
#   'num_characters': 10,
#   'character_deaths': {'Gen. Jack Gordon Shepherd': 1,
#    'Lt. Pavlov Dill': 1,
#    'Pvt. Duff Horton': 0,
#    'Cpl. Thom Kobe': 0,
#    'Pvt. Lei Sahara': 0,
#    'Capt. V.J. Dax': 0,
#    'Pvt. Charlie Soda': 0,
#    'TSgt. Ari Peck': 0,
#    'Cpl. Joe Griff': 0,
#    'Sgt. Dede Rake': 0}},
#  '8714658': {'num_deaths': 2,
#   'num_characters': 3,
#   'character_deaths': {'Raju': 1, 'Rosie Marco': 1, 'Bhola': 0}},
#  '163438': {'num_deaths': 2,
#   'num_characters': 8,
#   'character_deaths': {'Deirdre': 0,
#    'Vincent': 0,
#    'Larry': 1,
#    'Gregor': 0,
#    'Sam': 1,
#    "Seamus O'Rourke": 0,
#    'Jean-Pierre': 0,
#    'Natacha Kirilova': 0}},
#  '17544255': {'num_deaths': 2,
#   'num_characters': 5,
#   'character_deaths': {'Caleb Koestler': 0,
#    'Lucinda': 1,
#    'Abby': 0,
#    'Diana Wayland': 1,
#    'John Koestler': 0}},
#  '23292052': {'num_deaths': 2,
#   'num_characters': 10,
#   'character_deaths': {'Ben Selleck': 1,
#    'Don Ready': 0,
#    'Babs Merrick': 0,
#    'Jibby Newsome': 0,
#    'Brent Gage': 0,
#    'Blake': 0,
#    'Paxton Harding': 0,
#    'Ivy Selleck': 0,
#    'Stu Harding': 0,
#    'McDermott': 1}},
#  '11827016': {'num_deaths': 2,
#   'num_characters': 6,
#   'character_deaths': {'Remy': 1,
#    'Jake Freivald': 1,
#    'Carol': 0,
#    'Frank': 0,
#    'T-Bone': 0,
#    'Beth': 0}},
#  '737803': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Lloyd Christmas': 1,
#    'Harry Dunne': 1,
#    'Mary Swanson': 0,
#    'Nicholas Andre': 0}},
#  '515151': {'num_deaths': 2,
#   'num_characters': 6,
#   'character_deaths': {'John Henry Patterson': 1,
#    'Angus Starling': 0,
#    'Dr. David Hawthorne': 0,
#    'Abdullah': 0,
#    'Robert Beaumont': 0,
#    'Charles Remington': 1}},
#  '71473': {'num_deaths': 2,
#   'num_characters': 9,
#   'character_deaths': {'Holly Martins': 1,
#    'Harry Lime': 1,
#    'Sgt. Paine': 0,
#    'Maj. Calloway': 0,
#    "'Baron' Kurtz": 0,
#    'Popescu': 0,
#    'Anna Schmidt': 0,
#    'Dr. Winkel': 0,
#    'Man Chasing Holly': 0}},
#  '1256990': {'num_deaths': 2,
#   'num_characters': 6,
#   'character_deaths': {'Helen Lyle': 1,
#    'Candyman': 0,
#    "Bernadette 'Bernie' Walsh": 0,
#    'Anne-Marie McCoy': 0,
#    'Jake': 0,
#    'Trevor Lyle': 1}},
#  '24653': {'num_deaths': 2,
#   'num_characters': 6,
#   'character_deaths': {'Ashitaka': 1,
#    'Jigo': 0,
#    'San': 0,
#    'Moro': 0,
#    'Lady Eboshi': 1,
#    'Okkoto': 0}},
#  '24314116': {'num_deaths': 2,
#   'num_characters': 10,
#   'character_deaths': {'Joshamee Gibbs': 0,
#    'Captain Jack Sparrow': 0,
#    'King George II': 0,
#    'Hector Barbossa': 0,
#    'Captain Teague': 0,
#    'Angelica Teach': 1,
#    'Blackbeard': 1,
#    'Syrena': 0,
#    'Philip': 0,
#    'Spaniard': 0}},
#  '8615612': {'num_deaths': 2,
#   'num_characters': 2,
#   'character_deaths': {'Paulina Escobar': 1, 'Dr. Roberto Miranda': 1}},
#  '6222273': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Maurice': 1, 'Dave': 0, 'Loridonna': 0, 'Tony': 1}},
#  '1328239': {'num_deaths': 2,
#   'num_characters': 3,
#   'character_deaths': {'Evil Scholar': 1, 'Tong Pak Foo': 0, 'Chen Heung': 1}},
#  '27368886': {'num_deaths': 2,
#   'num_characters': 5,
#   'character_deaths': {'Governor Chip Majors': 1,
#    'Senator Edmonds': 1,
#    'Graham': 0,
#    'Cobbs': 0,
#    'Gloria': 0}},
#  '2485659': {'num_deaths': 2,
#   'num_characters': 3,
#   'character_deaths': {'Jim Raynor': 1, 'Dodd': 0, 'Kristen Cates': 1}},
#  '1605227': {'num_deaths': 2,
#   'num_characters': 9,
#   'character_deaths': {'Jane Coslaw': 0,
#    'Brady Kincaid': 0,
#    'Andy Fairton': 0,
#    'Sheriff Joe Haller': 0,
#    'Reverend Lowe': 1,
#    'Uncle Red': 0,
#    'Marty Coslaw': 1,
#    'Nan Coslaw': 0,
#    'Bob Coslaw': 0}},
#  '919477': {'num_deaths': 2,
#   'num_characters': 8,
#   'character_deaths': {'Aladar': 1,
#    'Suri': 0,
#    'Kron': 1,
#    'Bruton': 0,
#    'Url': 0,
#    'Neera': 0,
#    'Baylene': 0,
#    'Eema': 0}},
#  '16852170': {'num_deaths': 2,
#   'num_characters': 2,
#   'character_deaths': {'Danielle': 1, 'Drew': 1}},
#  '286544': {'num_deaths': 2,
#   'num_characters': 6,
#   'character_deaths': {'Leo Biederman': 1,
#    'Jenny Lerner': 1,
#    'Spurgeon Tanner': 0,
#    'President Tom Beck': 0,
#    'Sarah Hotchner': 0,
#    'Beth Stanley': 0}},
#  '1107088': {'num_deaths': 2,
#   'num_characters': 8,
#   'character_deaths': {'John Kreese': 0,
#    'Mr. Kesuke Miyagi': 0,
#    'Daniel Larusso': 1,
#    'Yukie': 0,
#    'Sato': 0,
#    'Kumiko': 1,
#    'Chozen': 0,
#    'Toshio': 0}},
#  '6339198': {'num_deaths': 2,
#   'num_characters': 11,
#   'character_deaths': {'Kool': 1,
#    'LaShawna': 0,
#    'Pee Wee': 0,
#    'C-Dawg': 0,
#    'Remo': 0,
#    'Master Keaton': 0,
#    'Tyrel': 1,
#    'Tully': 0,
#    'Saint': 0,
#    'Moe': 0,
#    'Officer Roberts': 0}},
#  '246963': {'num_deaths': 2,
#   'num_characters': 7,
#   'character_deaths': {'Lula Pace Fortune': 0,
#    'Sailor Ripley': 1,
#    'Marietta Fortune': 0,
#    'Johnnie Farragut': 0,
#    'Marcelles Santos': 0,
#    'Perdita Durango': 0,
#    'Bobby Peru': 1}},
#  '1347325': {'num_deaths': 2,
#   'num_characters': 6,
#   'character_deaths': {'Andre Toulon': 0,
#    'Alex Whitaker': 0,
#    'Dana Hadley': 0,
#    'Frank Forrester': 0,
#    'Neil Gallagher': 1,
#    'Megan Gallagher': 1}},
#  '4738587': {'num_deaths': 2,
#   'num_characters': 5,
#   'character_deaths': {'Princess Snow Kaguya': 1,
#    'Kakeru': 0,
#    'Luna': 0,
#    'Himeko Nayotake': 1,
#    'Sailor Moon': 0}},
#  '320496': {'num_deaths': 2,
#   'num_characters': 8,
#   'character_deaths': {'Marcus': 0,
#    'Lois': 0,
#    'Willie': 1,
#    'Bob Chipeska': 0,
#    'Sue': 0,
#    'Gin': 1,
#    'The Kid': 0,
#    'Roger Merman': 0}},
#  '20225956': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Rebecka': 1, 'Sara': 1, 'Leo': 0, 'Therese': 0}},
#  '2208130': {'num_deaths': 2,
#   'num_characters': 5,
#   'character_deaths': {'Traver': 1,
#    'Miller': 1,
#    'Evalyn': 0,
#    'Rev. Fleetwood': 0,
#    'Jackson': 0}},
#  '29075630': {'num_deaths': 2,
#   'num_characters': 9,
#   'character_deaths': {'Batman': 1,
#    'Bruce Wayne': 0,
#    'Jim Gordon': 0,
#    'Bane': 1,
#    'John Blake': 0,
#    'Miranda Tate': 0,
#    'Alfred Pennyworth': 0,
#    'Lucius Fox': 0,
#    'Young Talia al Ghul': 0}},
#  '2360074': {'num_deaths': 2,
#   'num_characters': 4,
#   'character_deaths': {'Ramesh': 1, 'Ganga': 0, 'Soumya': 0, 'Dr. Vijay': 1}},
#  '1172977': {'num_deaths': 2,
#   'num_characters': 3,
#   'character_deaths': {'Mallory': 0, 'Weaver': 1, 'Maritza': 1}},
#  '1633705': {'num_deaths': 2,
#   'num_characters': 3,
#   'character_deaths': {'Polly Cutler': 0,
#    'Rose Loomis': 1,
#    'George Loomis': 1}},
#  ...}

# %%
print(f'Number of movies = {len(records)}')
print(f'Number of characters = {np.sum([v['num_characters'] for k, v in records.items()])}')
print(f'Number of deaths = {np.sum([v['num_deaths'] for k, v in records.items()])}\n')

print(f'Average number of characters per movie = {np.mean([v['num_characters'] for k, v in records.items()]).round(2)}')
print(f'Average number of deaths per movie = {np.mean([v['num_deaths'] for k, v in records.items()]).round(2)}')
print(f'Average percentage of dead characters = {np.mean([v['num_deaths'] / v['num_characters'] for k, v in records.items()]).round(2)}')
# Out:
# Number of movies = 18990
# Number of characters = 57949
# Number of deaths = 7232
#
# Average number of characters per movie = 3.05
# Average number of deaths per movie = 0.38
# Average percentage of dead characters = 0.11

# %% [markdown]
# ## Examine specific case

# %%
character_bags = json.load(open('data/processed/character_bags_3238135.json'))

# %%
tokens = pd.read_csv('data/interim/corenlp_plot_summaries/tokens_3238135.csv')

# %%
" ".join(tokens['word'])
# Out:
# "The film begins with Simon and Greg planning to take a boat to an island rave party . They meet up with Alicia , Karma and Cynthia . Karma has a crush on Simon , Simon has a crush on Alicia and Cynthia is Greg 's girlfriend . When they arrive at the dock , they find the boat to take them to the island has already left . They hitch a ride instead with Victor Kirk and his first mate Salish . A cop named Jordan Casper tries to stop them since Kirk is a smuggler , but they leave anyway . Arriving at the island party site they find it a deserted mess . Alicia , Karma and Simon start searching for the others leaving Cynthia and Greg behind . The two start to making out in a tent , but Greg leaves to urinate . Left alone , Cynthia is killed by a group of zombies . Meanwhile , the others find an old house . Inside , they find Rudy , Liberty and Hugh who tell them zombies attacked the rave , killing everyone . The six go back to the rave site to get the others . Meanwhile , Salish is killed while walking through the forest . Everyone else meets up at the rave site . Cynthia shows up but she 's become a zombie . She kills Hugh but is shot by Casper . They develop a plan to leave the island using Kirk 's boat . But they find Kirk 's boat overrun by zombies . Casper and Greg leave the group to go find help , but Greg is killed . Kirk later takes the group to a hidden box of guns . Once everyone is armed , they head back to the house . The front of the house is filled with zombies . Liberty and Casper are killed in the ensuing fight while the rest manage to make it inside . Kirk hears Salish whistling outside . He goes out and finds Salish as a zombie . Kirk then commits suicide by blowing himself up , opening the front of the house . The remaining four lock themselves in a lab , but the zombies break in . Karma finds a hatch in the floor . She , Alicia and Rudy climb down while Simon shoots a barrel of gun powder , blowing up the house , a lot of zombies , and himself . They find themselves in a series of tunnels . Making their way through the tunnels , Karma is killed by zombies as she holds them off so Rudy and Alicia flee . They 're later captured by a man named Castillo `` wearing Greg 's face as a mask '' who injected himself with immortality serum many years ago , creating the first zombie . Alicia and Rudy escape , blowing the tunnels up in the process , but they 're followed by Castillo . Alicia gets into a sword duel with Castillo and he stabs her in the heart . Rudy decapitates Castillo , thinking the fight is over . But Castillo is still alive and his headless body begins to strangle Rudy . Alicia , who is barely alive , crushes the Castillo 's head under her feet , finally stopping him . She then seems to die . Later , Rudy and Alicia are seen being rescued by a team of federal agents . Rudy reveals his last name to be Curien . The ending narration reveals that Rudy gave Alicia the immortality serum and that is why she is alive ."
